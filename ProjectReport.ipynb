# %% [markdown]
# # Project Report
#
# ### Title: "Automatic Speaker Verification with Siamese Neural Networks"
# ### Student name: "Juuso Hämäläinen"

# %% [markdown]
# ## Abstract
#
# _In this project the goal was to generate Automatic Speaker Verification (AVS) system with Deep Neural Networks. For this purpose a Deep Convolutional Neural Network was created as the base model, which was then utilized as a part of Siamese Neural Network. Four different Siamese Neural Network models were trained to simulate different situations in speaker verification. Then the models were evaluated accordingly to provide information about how different scenarios affect the learning efficiency and prediction accuracy of the model._
#
# _Results indicate that with proper training more generalized Models could be proven semi-useful and transferable, thus this project did not provide too relevant results besides all efforts._

# %% [markdown]
# ## Introduction
#
# Describe the research question:
# * What is your hypothesis?
#
# > The hypothesis for this project is, that automatic speaker verification Models reliability, accuracy and and transferability are is highly dependent on the data used for the training and testing of the model and training Model with too biased data (or for too narrow scenarios), will have huge effect on the overall reliability of the Model.
#
# * What are the main issues are you tackling?
#
# > Main issues in this project are related to the inreliability of the Siamese Neural Networks
#
# * Break down your approach into steps and describe them.
#
# >Approach in this project consists on following steps:
#
# >1. Split the Data into four different Train-and Test Sets. Each including a different scenario. Scenarios are following: Basic-scenario, Text dependent scenario, text limited scenario, and text independent scenario.
#
# >2. Build Base-line Deep Convolutional Neural Network Model and Siamese Model based on the Base Model.
#
# >3. Train different Models with data correlating to different scenarios.
#
# >4. Evaluate Models with the Test Sets made for the scenario the Model was trained for.
#
# >5. Evaluate Models with Test Sets from other scenarios, than which the Model was trained for to see how transferable the Model would be and how much effect the training scenario has to transferability.
#
# Brief description of which dataset you are using.
#
# >In this project the AudioMNIST data set is used for training and testing the generated Models. AudioMNIST consists of 30000 utterances of spoken digits splitted evenly among 60 different speakers.
#
# How many different ways (approaches) you know that could be used to resolve the hypothesis?
#
# >It is notable, that there are many other ways to resolve the hypothesis, which might be useful to either try or even append to this project if further research is to be done. One worth mentioning is to use transfer learning, to utilize other data sets and/or use the Models generated and trained on this project with testing data out of the context, which they were trained on to see better the overall effects how the training data affects the predictions / evaluations of the Models.
#
# >Totally different approaches could be also used for training and testing the Models, like using a mel-spectrogram images and 2D Convolutional networks, or as provided in this paper (https://arxiv.org/pdf/1812.00271.pdf) to use chunks of MFCCs and mutual information calculations based on them with Deep Neural Network and using SincNet as proved in the same paper.
#
# >Also i-vertor, random forests and other approaches can also be utilized for this kind of a classification task.
#
# Why did you choose your specific approach?
#
# >This specific approach was chosen, because training four* different models and then evaluating them on the Test Set specified for the scenario and then evaluating the Model against Test Set from totally different scenario, would possibly provide information on which type of a training scenario would yield the most error tolerant / transferable Models.
#
# >>*(eight in total, if the Models trained with the other sampling scenario are included)
#
# What are the other methods' merits or drawbacks, and what are the advantages of your method?
#
# >The merits are, that the Siamese Deep Neural Network can be efficient and good way for running test simulations on binary classification task and it can provide good base-line for evaluating Models in transfer learning.
#
# >The drawbacks are, that as with all Neural Networks, finding the _goldilocks_ values for parameters are hard without using gridsearches etc, and also finding the optimal Model structure (the types and numbers of layers and activations to be utilize), is quite chalenging and time taking.
#
# >Other drawbacks are that as Neural Networks are usually bit of a black boxes and here we are trying to achieve a Model, which could be applicable for multiple different classification scenarios, finding the correct structure and values becomes even more difficult.
#
# What are the goals you achieved in this project?
# >Result wise this project has yield so far results, which indicate that Siamese Neural Networks can be utilized to make classifiers for speech data using MFCC-features. Yet the results have been slightly hars, due to lack of time spend optimizing and training the networks and due to little bit too biased training scenario, which lead to samples being too often providing same outcome (not same speakers). A way to compensate this was provided in this project, but it yielded not too great results either if the goal was to produce accurate ASV-system.
#
# > Even tho the training setup was biased, it was most useful for learning experience, as it provided insight on how the proper training of the Models should have been done, and gave a good look at the tools used to reduce the effects on the performance of the Models when dealing with highly homogenous or otherwise biased data sets.
#
# >Also, there has not been enough time to actually spend time on further anylizing the results yet or test trained models on other Test Set datas, so the information about how transferable different Models actually are is still missing, even tho, assumptions and conclusions could be drawn from the Models (and it looks like, they are not too transferable atleast in perspective, that they actually could have been used for speaker verification with other data sets)
#
# >Learning wise I have achieved to learn more about data processing in general and generating (Siamese) Deep Neural Network Models using Python. Also I have learned some tricks on data sampling and other more general data-science related methods, and have become more familiar with the tools used in this field.

# %% [markdown]
# # Methods
#
# There are three major components of a method you must describe:
#
# * _Programming_: which libraries is used for which purpose.
#
# > Utility libraries like zipfile, os, random etc. were used for data fetching from the source and for some of the pre-processing.
#
# > Most of the libraries used in this project were basic data-science libraries, like NumPy, Pandas and Sklearn. These libraries were used for processing data and to help utilizing the Neural Network Model.
#
# > Tensorflow.Keras and other tensorflow libraries were used for creating, training and testing the Neural Network Models.
#
# * _Data_: which dataset has been used to validate your hypothesis.
#
# >AudioMNIST data set was used for creating four different Train-and Test Sets simulating different scenarios in speaker verification.
#
# * _Algorithm_: which machine learning algorithms is used for the task, describe all the algorithm briefly as you could, a flow diagram or pseudocode is the best option if you have multiple-step in a algorithm.
#
# >The Machine Learning Algorithm for training the Siamese Neural Network model was following:
#
# >> get for DataFrame consisting of trainable pairs of utterances from all Train Set samples
#
# >> for sample pairs in DataFrame:
#
# >>>>take a sample pair
#
# >>>if pair from same speaker:
#
# >>>>set target variable y: y = 1, else set y = 0
#
# >>>>get MFCC-features from pairs
#
# >>>set and normalize weights based on occurances of same vs different speakers among all of the formed pairs
#
# >>>train siamese model(inputs=[mfcc_feats1, mfcc_feats2], target = y, weights={w_different, w_same})
#
# >In the algorithm, the input samples (MFCC-features) are passed into a Siamese Neural Network Model, which consists of Deep Concolutional Neural Network Model, which is used for both samples (for weigth sharing).
#
# >Then the results are mapped into two feature maps and embedded together. Then eouclidean distance is calculated for both feature maps, in order to determine, the similarity among the samples.
#
# > Finally a single sigmoided number is outputted from the output layer indicating if the speakers were same(close to 1) or different (close to 0).

# %% [markdown]
# ## Used libraries
#
# Just provide a list of library you used here, and write a (very short) description of their function (or why you use them). For example:
#
# * _numpy_: for data processing and utility functions.
# * _pandas_: for data processing and saving Train-and Test Sets.
# * _sklearn.metrics import det_curve, DetCurveDisplay_: for evaluation visualization
# * _sklearn.model_selection import train_test_split_: for generating training and test sets without looping.
# * _tensorflow_: for tensorflow.keras usage.
# * _tensorflow import keras_: for generating, training and testing neural Network Models.
# * _tensorflow.keras.callbacks import ModelCheckpoint_: for generating checkpoints during training of Neural Network.
# * _tensorflow.keras.layers import Input_: for setting inputs to be passed into Siamese Neural Network Model.
# * _tensorflow.keras.layers import Subtract, Lambda_: for embedding the feature maps and calculating the euclidean distance between them.
# * _tensorflow.keras.models import Model_: for Siamese Neural Network Model creation.
# * _tensorflow.keras.backend_: for utilixing keras backend functions on embedding and euclidean distance calculations.
# * _librosa_: for audio signal processing.
# * _librosa import display_: for displaying audio data.
# * _os, glob, pathlib, zipfile_: for data pre-processing.
# * _urllib.request import urlretrieve_: for fetching AudioMNIST data.
# * _matplotlib_: for data visualization

# %% [markdown]
# Run the following line to install nighty build of sklearn before importing libraries (uninstall of old sklearn required):

# %%
# !pip uninstall scikit-learn -y
# !pip install --pre --extra-index https://pypi.anaconda.org/scipy-wheels-nightly/simple scikit-learn
# Out:
# Uninstalling scikit-learn-0.22.2.post1:
#   Successfully uninstalled scikit-learn-0.22.2.post1
# Looking in indexes: https://pypi.org/simple, https://pypi.anaconda.org/scipy-wheels-nightly/simple
# Collecting scikit-learn
#   Downloading https://files.pythonhosted.org/packages/f3/a5/4743a303debe2f57cd10a9f9ec0a7cc6c265b96f12cfb3310d522e459ded/scikit_learn-0.24.0rc1-cp36-cp36m-manylinux2010_x86_64.whl (22.2MB)
#      |████████████████████████████████| 22.2MB 1.4MB/s
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from scikit-learn) (1.18.5)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.6/dist-packages (from scikit-learn) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn) (0.17.0)
# Collecting threadpoolctl>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/f7/12/ec3f2e203afa394a149911729357aa48affc59c20e2c1c8297a60f33f133/threadpoolctl-2.1.0-py3-none-any.whl
# Installing collected packages: threadpoolctl, scikit-learn
# Successfully installed scikit-learn-0.24.0rc1 threadpoolctl-2.1.0

# %%
# Import ds libraries.
import numpy as np
import pandas as pd
from sklearn.metrics import det_curve, DetCurveDisplay
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.layers import Input, Subtract, Lambda
from tensorflow.keras.models import Model
import tensorflow.keras.backend as K

# Import audio libraries.
import librosa
from librosa import display

# Import utilities.
import os
import glob
from urllib.request import urlretrieve
from pathlib import Path
import random
from zipfile import ZipFile
import ast

# Import plotting
import matplotlib.pyplot as plt

# %% [markdown]
# ## Datasets
#
# What are the features in the given dataset?
#
# >The data set consists of wavefiles, containing utterances from spoken digits between numbers 0-9. From the audio file, many features could have been draw, from different spectrogram presentations, to differently splitted signal samples and to MFCC-features and chunks of them and also filter-banks and their representative variations.
#
# How do you split the dataset for training and evaluation?
#
# >The data set was split into four different Train and Test Sets as following:
#
# >Basic scenario: Data is split into Train Set containing 20000 samples from 40 speakers and Test Set containing 10000 samples from 20 other speakers.
#
# >Text dependent scenario: Data is split into Train Set containing 1500 samples
# from single spoken utterance and Test set containing an other 1500 samples from the same spoken digit from different utterances.
#
# >Text limited scenario: Data is split into Train Set containing 15000 samples consisting of 50% of the utterances per digit per speaker and Test Set containing 15000 samples consisting the other half of the data.
#
# >Text independent scenario: Data is split into Train Set containing of 15000 samples consisting of all utterances from five randomly chosen digits and Test Set containing 15000 samples consisting of all utterances from the remaining 5 digits.
#
# Which features (input variables) are you going to use?
#
# >The MFCC-features were taken from the utterances for each set and used as the inputs for the Deep Neural Network.
#
# Which target variables are needed?
#
# >The target variable needed for training, is simply the binary-classification if the two samples about to be prcessed via the Model are from the same or not the same speaker.
#
# >The target variables for testing for all scenarios except the *basic scenario* were also based on the binary classifications if the Test Set samples were from the same speaker or not. For the *basic scenario*, *target score* and *non-target score* sets with sizes of 10 and 50 samples, were separated from the Test Set and used for predicting and evaluating the Model.
#
# What is the possible connection between these variables?
#
# > The connection between the variables is in the class, which they represent.

# %% [markdown]
# First we have to define couple of basic functions, in order to get the splitting done correctly

# %%
# Directory scan function.
def dirscan(dir):
    subfolders = [f.path for f in os.scandir(dir) if f.is_dir()]
    for dir in list(subfolders):
        subfolders.extend(dirscan(dir))
    return subfolders

# %%
# Define pre-emphasis function.
def preemphasis(signal, coeff=0.95):

    # Emphassized signal
    signal_out = np.append(signal[0], signal[1:] - coeff * signal[:-1])

    # Convert to numpy-array.
    signal_out = np.array(signal_out)

    # Return pre-emphasized signal
    return signal_out


# Get MFCCs.
def mfccs(file_path: str,
          preemphasis_coeff: float = 0.95,
          n_fft: int = 512,
          winlen: float = 0.025,
          winstep: float = 0.01,
          n_filter_banks: int = 40,
          n_mfccs: int = 13,
          winfunc: callable = np.hamming,
          sampling_rate=8000,
          verbose: bool = False) -> np.ndarray:

    # Reassemble the sampling rate if needed.
    y, sr = librosa.load(file_path, sr=None)
    if sr != sampling_rate:
        y = librosa.resample(y, orig_sr=sr, target_sr=sampling_rate)

    # Pre-emphasize the signal.
    y = preemphasis(y, preemphasis_coeff)

    # Define window length and hop-length.
    window_length = int(winlen * sampling_rate)
    hop_length = int(winstep * sampling_rate)

    # Get magnitude spectrogram.
    spectrogram = np.abs(librosa.stft(y,
                                      n_fft=n_fft,
                                      hop_length=hop_length,
                                      win_length=window_length,
                                      center=False))
    # Get mel-spectrogram.
    mel_spectrogram = librosa.feature.melspectrogram(S=spectrogram)

    # Get MFCC features from the mel-spectrogram..
    mfccs = librosa.feature.mfcc(S=np.log(mel_spectrogram), n_mfcc=n_mfccs)

    # Normalize MFCCs by mean and standard-deviation.
    mfccs_norm = mfccs - np.mean(mfccs, axis=1, keepdims=True)
    mfccs_norm /= np.std(mfccs, ddof=0, axis=1, keepdims=True)

    # Visualization for debugging
    if verbose:
        plt.figure(figsize=(10, 12))
        librosa.display.waveplot(y, sr=sr, ax=plt.subplot(3, 2, 1))
        plt.gca().set_title('Wave plot')
        librosa.display.specshow(librosa.amplitude_to_db(spectrogram),
                                 sr=sr,
                                 hop_length=hop_length,
                                 fmax=sampling_rate / 2,
                                 y_axis='linear',
                                 x_axis='time',
                                 ax=plt.subplot(3, 2, 2))
        plt.gca().set_title('Spectrogram')
        librosa.display.specshow(librosa.amplitude_to_db(mel_spectrogram),
                                 sr=sr,
                                 hop_length=hop_length,
                                 fmax=sampling_rate / 2,
                                 y_axis='mel',
                                 x_axis='time',
                                 ax=plt.subplot(3, 2, 3))
        plt.gca().set_title('Mels-Spectrogram')
        librosa.display.specshow(librosa.amplitude_to_db(mfccs),
                                 sr=sr,
                                 fmax=sampling_rate / 2,
                                 x_axis='time',
                                 hop_length=hop_length,
                                 ax=plt.subplot(3, 2, 4))
        plt.gca().set_title('MFCCs')
        ax = plt.subplot(3, 2, 5)
        ax.plot(mfccs)
        ax.set_title('Individual MFCC features')
        ax = plt.subplot(3, 2, 6)
        ax.plot(mfccs_norm)
        ax.set_title('Normalized MFCCs')
        plt.tight_layout()
    return mfccs_norm.T

# %%
# Function for unifying MFCC frame-length.
def unify_mfcc(standard_length, mfcc):

    # If maximum length > frame length, do padding to end.
    if (standard_length > mfcc.shape[0]):
        pad_width = standard_length - mfcc.shape[0]
        mfcc = np.pad(mfcc, ((0,pad_width), (0,0)), mode='constant', constant_values=(0,0))

    # Else do cutoff from end.
    else:
        mfcc = mfcc[:standard_length, :]

    # Return unified MFCC.
    return mfcc

# %% [markdown]
# Download the data set and get utterances:

# %%
# Download data set and extract files.
url = r"https://github.com/soerenab/AudioMNIST/archive/master.zip"
filename = "/tmp/data.zip"
if not os.path.exists(filename):
    print('Downloading AudioMNIST dataset ...')
    urlretrieve(url, filename=filename)
path = '/tmp/AudioMNIST-master/data'
if not os.path.exists(path):
    print("Extracting files from AudioMNIST...")
    with ZipFile(filename, mode='r') as f:
        f.extractall(path="/tmp")
# Out:
# Downloading AudioMNIST dataset ...
# Extracting files from AudioMNIST...

# %%
# Get utterances.
path = "/tmp/AudioMNIST-master/data"
subfolders = dirscan(path)

utterances = []

# Iterate through subfolders and add all wavfiles under same variable.
for folder in subfolders:
    path = Path(folder).absolute()
    for wavefile in glob.glob(os.path.join(path, '*.wav')):
        utterances.append(wavefile)

np.random.shuffle(utterances)

metadata = [os.path.basename(i).split('_')[:-1] for i in utterances]
digits = np.array([i[0] for i in metadata])
speakers = np.array([i[1] for i in metadata])

print(utterances[:5])
print(metadata[:5])
print(digits[:5])
print(speakers[:5])
# Out:
# ['/tmp/AudioMNIST-master/data/16/8_16_12.wav', '/tmp/AudioMNIST-master/data/15/4_15_9.wav', '/tmp/AudioMNIST-master/data/19/0_19_29.wav', '/tmp/AudioMNIST-master/data/03/6_03_38.wav', '/tmp/AudioMNIST-master/data/03/0_03_5.wav']
# [['8', '16'], ['4', '15'], ['0', '19'], ['6', '03'], ['0', '03']]
# ['8' '4' '0' '6' '0']
# ['16' '15' '19' '03' '03']

# %% [markdown]
# You can mount your Google Drive, if you want to save following csv-files etc to you Drive:

# %%
# Mount Google Drive.
from google.colab import drive

drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# Create set of unique speakers for later use:

# %%
# Unique speakers.
speakers_set = np.unique(speakers)

# %% [markdown]
# Following code block is the most time-requiring among data processing as it loads the whole mfcc-features set and also creates the "main" DataFrame from the utterances and it's metadata (depending on machine, usually took ~20min with GPU-acceleration and using NVidia GTX1050 on local machine and ~1h with Colab). After run once, this block can be skipped by loading the saved Pickle-file. (if needed, you can also load it to you Google Drive in order to not be distracted by the runtime-disconnection issues)

# %%
# Split to Train Sets and Test Sets based on following conditions:

# DataFrame containing all utterances, speakers and digits.
all_data = pd.DataFrame()

# Counter variable.
counter = 0

# Define standard length for frames in MFCC.
standard_length = 60

# For utterance.
for file in utterances:
    # Do processing into utterance, digit and speaker.
    splitted = os.path.basename(file).split('_')[:-1]
    digit = int(splitted[0])
    speaker = int(splitted[1])  # Get rid of zeros for easier indexing.
    feats = mfccs(file) # Get mfcc.
    #Reshape to rough estimate in order to maintain unified shape between samples.
    feats = unify_mfcc(standard_length, feats)
    # Just in case save also to its own 3D array.
    all_data = all_data.append(pd.DataFrame({"utt": ["{}".format(file)], "dgt": [digit], "spk": [speaker], "mfcc": [feats]}, index=[counter]))
    counter += 1

# Save to Pickle for later use to runtime.
all_data.to_pickle("/tmp/meta_mfcc.pkl")

# %% [markdown]
# Run the following block if you want to save Pickle to your Drive:

# %%
# Save Pickle to Google Drive. Path can be changed if wanted to specify different folder.
path = "/content/drive/MyDrive/meta_mfcc.pkl"
all_data.to_pickle("{}".format(path))

# %% [markdown]
# Run the following block if you want to load the Pickle from runtime:

# %%
# Load Pickle from runtime (if still there)
all_data = pd.read_pickle("/tmp/meta_mfcc.pkl")
print(all_data.head())

# %% [markdown]
# Run the following if you want to load Pickle from the Google Drive:

# %%
# Load Pickle from Google Drive.
path = "/content/drive/MyDrive/meta_mfcc.pkl"
all_data = pd.read_pickle("{}".format(path))
print(all_data.head())
# Out:
#                                           utt  ...                                               mfcc
# 0  /tmp/AudioMNIST-master/data/55/0_55_33.wav  ...  [[-1.6598772413978737, -0.30298199689743655, 0...
# 1  /tmp/AudioMNIST-master/data/18/5_18_19.wav  ...  [[-1.0717696081484203, 0.6127292772012218, 0.4...
# 2  /tmp/AudioMNIST-master/data/20/9_20_48.wav  ...  [[-1.722397497848225, -0.7395156237618239, -0....
# 3  /tmp/AudioMNIST-master/data/12/9_12_35.wav  ...  [[-1.9336332534678515, -0.0671029092543321, 2....
# 4  /tmp/AudioMNIST-master/data/10/3_10_49.wav  ...  [[-1.692700028046417, -0.8166032248588326, -0....
#
# [5 rows x 4 columns]

# %% [markdown]
# Split data into 4 different Train Sets and Test Sets:

# %%
"""Train Set and Test Set 1: Contains "basic" scenario, where all data is splitted into Train Set and Test Set, later on the train set 
is used to train the network by picking random samples from the Train Set and is then tested using "target scores" containing 10 randomly 
chosen utterances from the same speaker and 50 randomly chosen utterances from an other speaker on the Test Set. Please notice, that the
target scores and non-target scores are generated from the Test Set in the evaluation phase and only the main Set for testing is generated 
here."""

# Train Set 1.
train_set_basic = pd.DataFrame()

# Test Set 1.
test_set_basic = pd.DataFrame()

# New speakers set (formatted).
speakers_set_formatted = []

# Process digits away from unique speakers set.
for speaker in speakers_set:
    speaker = int(str(speaker))
    speakers_set_formatted.append(speaker)

# Take 40 speakers at random from the  spekers_set as Training Set.
train_spk = []
sample_speakers = random.sample(list(speakers_set_formatted), len(speakers_set_formatted) - 20)
for speaker in sample_speakers:
    train_spk.append(speaker)

# Take remaining 20 speakers (not in Train Set) as Test Set.
test_spk = []
for speaker in speakers_set_formatted:
    if np.isin(speaker, train_spk) == False:
        test_spk.append(speaker)

# For each speaker in Train Set speakers.
for i in range(len(train_spk)):
    wanted = train_spk[i]
    speaker = all_data["spk"] == wanted
    train_set_basic = train_set_basic.append(all_data[speaker])

# For each speaker in Test Set speakers.
for i in range(len(test_spk)):
    wanted = test_spk[i]
    speaker = all_data["spk"] == wanted
    test_set_basic = test_set_basic.append(all_data[speaker])

print("Train Set Basic head:\n {}\nShape: {}".format(train_set_basic.head(), train_set_basic.shape))
print("Test Set Basic head:\n {}\nShape: {}".format(test_set_basic.head(), test_set_basic.shape))


plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.hist(train_set_basic["spk"])
plt.xlabel("Speaker ID")
plt.ylabel("Samples")
plt.title('Train Set Basic speakers')
plt.subplot(1, 2, 2)
plt.hist(test_set_basic["spk"])
plt.xlabel("Speaker ID")
plt.ylabel("Samples")
plt.title('Test Set Basic speakers')
plt.tight_layout()
plt.show()
# Out:
# Train Set Basic head:
#                                              utt  ...                                               mfcc
# 42   /tmp/AudioMNIST-master/data/37/4_37_11.wav  ...  [[-2.0416323427488767, -0.378214711946386, 2.1...
# 99   /tmp/AudioMNIST-master/data/37/2_37_36.wav  ...  [[-1.5590215415063755, -0.4147074358523019, 0....
# 103  /tmp/AudioMNIST-master/data/37/0_37_31.wav  ...  [[-1.609324314668372, -0.22964813605948833, 0....
# 160   /tmp/AudioMNIST-master/data/37/9_37_9.wav  ...  [[-1.5584813965339246, 0.12178748806296975, 1....
# 301  /tmp/AudioMNIST-master/data/37/1_37_34.wav  ...  [[-1.4596092846024487, -1.7970197927118534, 0....
#
# [5 rows x 4 columns]
# Shape: (20000, 4)
# Test Set Basic head:
#                                             utt  ...                                               mfcc
# 16  /tmp/AudioMNIST-master/data/02/9_02_20.wav  ...  [[-1.7590219767977562, -0.5020183117798674, 0....
# 26  /tmp/AudioMNIST-master/data/02/3_02_45.wav  ...  [[-1.5516006097188526, 0.3157818972285383, -0....
# 30   /tmp/AudioMNIST-master/data/02/0_02_3.wav  ...  [[-2.0463478620224462, -1.301806219544161, 0.8...
# 41  /tmp/AudioMNIST-master/data/02/9_02_10.wav  ...  [[-1.3458116888427678, 0.29821489571269605, 0....
# 57  /tmp/AudioMNIST-master/data/02/3_02_24.wav  ...  [[-1.4259989348859936, -0.5695182710419169, 0....
#
# [5 rows x 4 columns]
# Shape: (10000, 4)

# %%
"""Train Set and Test Set 2: Contains context Dependent data (only same digit)
   Data is splitted so, that the Train Set and Test set both contain only same digits from all speakers
   for example digit 1 from all speakers. Train Set contains 50% of the digits and the Test set other 50%.
   Note that the 50% mark is not necessarily the splitting distribution between the digits spoken from same speaker 
   (set may contain 100% of digits y from speaker x and 0% from an other in this scenario)."""

# Variable to define which digit is used for set making.
used_digit = 4

# DF for all utterances from chosen digit.
all_utts_from_digit = pd.DataFrame()

# Get all utts based on digit.
wanted = all_data["dgt"] == used_digit
all_utts_from_digit = all_data[wanted]

# Train Set 2.
train_set_dependent = pd.DataFrame()

# Test Set 2.
test_set_dependent = pd.DataFrame()

# Split into half, other half as Train Set and other as Test set.
train_set_dependent, test_set_dependent = train_test_split(all_utts_from_digit, test_size=0.5)

print("Train Set context Dependent head:\n {}\nShape: {}".format(train_set_dependent.head(), train_set_dependent.shape))
print("Test Set context Dependent head:\n {}\nShape: {}".format(test_set_dependent.head(), test_set_dependent.shape))

plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.hist(train_set_dependent["spk"])
plt.xlabel("Speaker ID")
plt.ylabel("Samples")
plt.title('Train Set Dependent speakers')
plt.subplot(1, 2, 2)
plt.hist(test_set_dependent["spk"])
plt.xlabel("Speaker ID")
plt.ylabel("Samples")
plt.title('Test Set Dependent speakers')
plt.tight_layout()
plt.show()
# Out:
# Train Set context Dependent head:
#                                                utt  ...                                               mfcc
# 23817  /tmp/AudioMNIST-master/data/45/4_45_25.wav  ...  [[-1.0354671132796067, -1.434044642736462, 0.5...
# 669    /tmp/AudioMNIST-master/data/50/4_50_26.wav  ...  [[-1.5426158834443684, -0.9477422808596948, 2....
# 29489  /tmp/AudioMNIST-master/data/04/4_04_45.wav  ...  [[-1.8481586997165684, -0.2802660996737049, 1....
# 4379   /tmp/AudioMNIST-master/data/34/4_34_31.wav  ...  [[-2.320805005532491, -2.2408987432780654, 1.9...
# 8595   /tmp/AudioMNIST-master/data/28/4_28_48.wav  ...  [[-0.8394624119887888, -2.075875951864114, 1.5...
#
# [5 rows x 4 columns]
# Shape: (1500, 4)
# Test Set context Dependent head:
#                                                utt  ...                                               mfcc
# 19041  /tmp/AudioMNIST-master/data/39/4_39_21.wav  ...  [[-1.637063382078565, -0.508325169501886, 1.88...
# 11310  /tmp/AudioMNIST-master/data/59/4_59_35.wav  ...  [[-1.312041148277697, -1.268522783400142, 1.30...
# 17087  /tmp/AudioMNIST-master/data/50/4_50_14.wav  ...  [[-1.3662849452427357, -2.212853823617963, 1.5...
# 6283   /tmp/AudioMNIST-master/data/33/4_33_27.wav  ...  [[-1.9799318183104426, -0.30713785981175395, 2...
# 23868  /tmp/AudioMNIST-master/data/28/4_28_39.wav  ...  [[-1.7860319780327938, -1.2156145195333177, 1....
#
# [5 rows x 4 columns]
# Shape: (1500, 4)

# %%
"""Train Set and Test Set 3: Contains context Limited data, where the whole data set is included.
   With this setup, 50% of the digits and utterances per speaker are distributed into Train Set and the other 50% into Test Set."""

# Train Set 3.
train_set_limited = pd.DataFrame()

# Test Set 3.
test_set_limited = pd.DataFrame()

# For number of digits.
for j in range(0, 10):
    # For number of speakers.
    for i in range(1, 61):

        # Get speaker and digit according to loop iterators.
        speakers = all_data["spk"] == i
        digits = all_data["dgt"] == j

        # Gather data cells from DF, where digit and speaker are
        # corresponding to the loop iterators.
        data = all_data[speakers & digits]

        # Divider for the halves to be added to sets.
        train_temp, test_temp = train_test_split(data, test_size=0.5)

        # Append halves to actual sets.
        train_set_limited = train_set_limited.append(train_temp)
        test_set_limited = test_set_limited.append(test_temp)

print("Train Set Text Limited head:\n {}\nShape: {}".format(train_set_limited.head(), train_set_limited.shape))
print("Test Set Text Limited head:\n {}\nShape: {}".format(test_set_limited.head(), test_set_limited.shape))

plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.hist(train_set_limited["spk"])
plt.xlabel("Speaker ID")
plt.ylabel("Samples")
plt.title('Train Set Limited speakers')
plt.subplot(1, 2, 2)
plt.hist(test_set_limited["spk"])
plt.xlabel("Speaker ID")
plt.ylabel("Samples")
plt.title('Test Set Limited speakers')
plt.tight_layout()
plt.show()
# Out:
# Train Set Text Limited head:
#                                                utt  ...                                               mfcc
# 7527   /tmp/AudioMNIST-master/data/01/0_01_11.wav  ...  [[-1.3824170591836535, -0.6391017380863188, 0....
# 21947  /tmp/AudioMNIST-master/data/01/0_01_38.wav  ...  [[-1.4185669966237022, -0.6484204120144171, 0....
# 10146  /tmp/AudioMNIST-master/data/01/0_01_30.wav  ...  [[-1.7177400977846653, 0.1488297165138202, 0.5...
# 21484  /tmp/AudioMNIST-master/data/01/0_01_36.wav  ...  [[-2.079316338903819, 0.41537173962869883, 1.1...
# 23983  /tmp/AudioMNIST-master/data/01/0_01_40.wav  ...  [[-2.0106675605356203, -0.027129412889642213, ...
#
# [5 rows x 4 columns]
# Shape: (15000, 4)
# Test Set Text Limited head:
#                                                utt  ...                                               mfcc
# 22069  /tmp/AudioMNIST-master/data/01/0_01_20.wav  ...  [[-1.7798235550579473, -0.2442550973403971, 0....
# 3775   /tmp/AudioMNIST-master/data/01/0_01_31.wav  ...  [[-1.3356668509373426, -0.141583097186705, 1.1...
# 15772  /tmp/AudioMNIST-master/data/01/0_01_48.wav  ...  [[-1.904525858670501, -0.09960217809371678, 1....
# 6447   /tmp/AudioMNIST-master/data/01/0_01_22.wav  ...  [[-1.9937643097450393, -0.26570902633316323, 1...
# 8095   /tmp/AudioMNIST-master/data/01/0_01_10.wav  ...  [[-2.050242655387208, 0.14930026894741072, 0.4...
#
# [5 rows x 4 columns]
# Shape: (15000, 4)

# %%
"""Train Set and Test Set 4: Contains context Independent data, where Train Set contains all utterances of 5 digits from the Data Set
   and the Test Set contains an other 5 digits from the Data Set (which are not in the Train Set)"""

# Generate list of digits from 0-9.
generated_digits = []
for i in range(10):
    generated_digits.append(i)

# Take digits for Train Set from generated list using random sampling.
train_digits = random.sample(list(generated_digits), len(generated_digits) // 2)

# Populate Test Set digits from the ones which were not included into Train Set digits.
test_digits = []
for digit in generated_digits:
    if np.isin(digit, train_digits) == False:
        test_digits.append(digit)

print("Train Set digits: {}".format(train_digits))
print("Test Set digits: {}".format(test_digits))

# Train Set 4.
train_set_independent = pd.DataFrame()

# Test Set 4.
test_set_independent = pd.DataFrame()

for i in range(5):
    wanted = train_digits[i]
    wanted_digit = all_data["dgt"] == wanted
    train_set_independent = train_set_independent.append(all_data[wanted_digit])
for j in range(5):
    wanted = test_digits[j]
    wanted_digit = all_data["dgt"] == wanted
    test_set_independent = test_set_independent.append(all_data[wanted_digit])

print("Train Set context Independent head:\n {}\nShape: {}".format(train_set_independent.head(), train_set_independent.shape))
print("Test Set context Independent head:\n {}\nShape: {}".format(test_set_independent.head(), test_set_independent.shape))

plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.hist(train_set_independent["spk"])
plt.xlabel("Speaker ID")
plt.ylabel("Samples")
plt.title('Train Set Independent speakers')
plt.subplot(1, 2, 2)
plt.hist(test_set_independent["spk"])
plt.xlabel("Speaker ID")
plt.ylabel("Samples")
plt.title('Test Set Independent speakers')
plt.tight_layout()
plt.show()
# Out:
# Train Set digits: [2, 6, 7, 3, 5]
# Test Set digits: [0, 1, 4, 8, 9]
# Train Set context Independent head:
#                                             utt  ...                                               mfcc
# 10  /tmp/AudioMNIST-master/data/22/2_22_18.wav  ...  [[-1.3034085567165998, -0.5733265458940728, -1...
# 15  /tmp/AudioMNIST-master/data/45/2_45_11.wav  ...  [[-1.750461115340867, -0.6278926245958546, 1.6...
# 38   /tmp/AudioMNIST-master/data/43/2_43_9.wav  ...  [[-1.9935342854488374, -0.4891830639994723, 0....
# 39  /tmp/AudioMNIST-master/data/07/2_07_33.wav  ...  [[-1.5479923278061796, -0.5496796352273174, 1....
# 76  /tmp/AudioMNIST-master/data/09/2_09_22.wav  ...  [[-2.2644805773156014, -0.8159421918706462, 0....
#
# [5 rows x 4 columns]
# Shape: (15000, 4)
# Test Set context Independent head:
#                                             utt  ...                                               mfcc
# 0   /tmp/AudioMNIST-master/data/55/0_55_33.wav  ...  [[-1.6598772413978737, -0.30298199689743655, 0...
# 21  /tmp/AudioMNIST-master/data/05/0_05_42.wav  ...  [[-1.3480349951924993, -1.3502152355913966, 0....
# 22  /tmp/AudioMNIST-master/data/01/0_01_39.wav  ...  [[-1.8394532693761803, 0.10041460313206439, 0....
# 25  /tmp/AudioMNIST-master/data/59/0_59_38.wav  ...  [[-1.869185572089301, -0.044880296536494606, 0...
# 27  /tmp/AudioMNIST-master/data/22/0_22_12.wav  ...  [[-1.906001070998719, -1.437938409726864, 1.07...
#
# [5 rows x 4 columns]
# Shape: (15000, 4)

# %% [markdown]
# You can test MFCC-fetching with this premade function (fetches MFCCs of one utterance per Set and visualized the process):

# %%
# Testing MFCC-fetch once for each set to see they work.
def test_mfcc_fetch():
    # Set verbose to True, if you want to plot the results.
    
    # Context Basic Sets.
    _ = mfccs(train_set_basic["utt"].iloc[0], verbose=True)
    _ = mfccs(test_set_basic["utt"].iloc[0], verbose=True)

    # Context Dependent Sets.
    _ = mfccs(train_set_dependent['utt'].iloc[0], verbose=True)
    _ = mfccs(test_set_dependent['utt'].iloc[0], verbose=True)

    # Context Limited Sets.
    _ = mfccs(train_set_limited['utt'].iloc[0], verbose=True)
    _ = mfccs(test_set_limited['utt'].iloc[0], verbose=True)

    # Context Independent Sets.
    _ = mfccs(train_set_independent['utt'].iloc[0], verbose=True)
    _ = mfccs(test_set_independent['utt'].iloc[0], verbose=True)

test_mfcc_fetch()

# %% [markdown]
# Write down some critical analysis of the data, for example, the data is imbalance, some biases might be presented in the classifier.
#
# > Data is pretty decently distributed overall, but the Train Sets and Test Sets for some of the scenarios are definitely biased by the fact that for example the context dependent set is both trained and tested on the utterances from the same digit, which obviously should affect the classification results (as it is more likely that even the different speakers sound more similar saying same digits) and also other sets are affected by similar type of scenarios.
#
# > Also some bias can be randomly generated depending on the batch, as there might be a lack of samples from one speaker in a Set and thus it affects the training results.
#
# > However this is purposeful for testing the scenarios and later on  as it would be sufficient to see how the Models trained in a biased environment would do with classification tasks on other Test Sets, which is why the data splitting in this manner is beneficial.

# %% [markdown]
# ## Model description
#
# Which algorithm you used for solving the task?
#
# > Siamese Deep Neural Network was trained using custom algorithm provided earlier in this notebook on section **Methods**
#
# Write down technical description of the algorithm (maths and steps).
#
# * How to initialize the model?
# >The model is initialized in two steps:
#
# >>> 1: The Base Model is created, consisting of Deep Convolutional Neural Network, with 2 Convolutional layer, followed by 2 Maximum Pooling layers. Then 2 more Convolutional layers are applied and finally 2 Dense layers, with ReLU activation are applied. Batch normalization was also applied to all Convolutional layers.
#
# >>>2: The Siamese Deep Neural Network Model is initilized with 2 input layers, which are connected to the Base-line Model. Then the results from the base-line Model are mapped into feature maps for each input in the Siamese Model. After that, the feature map embedding is applied and euclidean distance between them is calculated. Finally a Dense output layer with sigmoid activation is applied to provide prediction of the class.
#
# >>> Adam-optimizer with learning rate = 0.001, with loss = Binary-crossentropy and with metrics = binary-accuracy was used for the Model.
#
# * Which parameters are important and relevant for our dataset?
#
# > The most important parameters are the similarity scores calculated from the two input features (MFCC-features).
#
# * How we fit the model?
#
# > All Models are fitted in a training function, where the corresponding Train Set is devided into pairs, from which the actual similarity (target score) is calculated and then the mfcc-features are separated. We feed all the pairs to the network, with their corresponding target scores, and then the Model is trained for chosen number of epochs in quite large batches based on the Train Set size.
#
# > Also a funtionality to fit the Model with less biased Data is afforded in this project and used for training four other Models for reference.
#
# > As the some of the data sets are biased in a way, that the propability of the same speaker is much lower than the probability of speakers being different, the weights are adjusted based on the calculated number of occurances of cases where the speakers in the pairwise splitted set are actually the same.
#
# * How do we perform prediction and evaluation with the model?
#
# > Model is predicted and evaluated in very similar manner as the fitting of the model is done, except we are using the pre-splitted Test Sets instead of Train Sets, the weights are not adjusted, and the  prediction is done without Model knowing the right value of the class.
#
# > For the basic scenario, the data is split into target scores and non-target scores for this purpose, and values from those are used, instead of the pairs.
#
# > For all of the Models predictions and evaluations were also drawn from multiple other Data Sets beyound the dedicated Test Set and the Models can be thus compared performance wise against each other to see if some of them were actually more transferable than others.
#
# Then provide the implementation below.
#
# **NOTE**: _To show your understanding, it is the best to provide a flow diagram or a figure of model component, you could inlcude an image using the following code_
#
# `<img src="..." alt="..." width="700"/>`
#
# <img src="https://drive.google.com/uc?export=view&id=1ZOEuy1Q46IaEa_Ta3C1UWm0QmIoe_YCV" alt="Siamese Neural Network Model" width="500"/>

# %% [markdown]
# Build Base Model:

# %%
# Build Base Model for Siamese Neural Network.
def build_model():
    # Create base model.
    base_model = keras.Sequential([

        # 2 times convolutions and max pooling.
        keras.layers.Conv2D(name="1_C", filters=32, kernel_size=(5,5), padding="same", input_shape=(60, 13, 1), activation ="relu"),
        keras.layers.BatchNormalization(),
        keras.layers.MaxPool2D(name="M_1", pool_size=2, strides=2),

        keras.layers.Conv2D(name="2_C", filters=40, kernel_size=(5,5), padding="same", activation="relu"),
        keras.layers.BatchNormalization(),
        keras.layers.MaxPool2D(name="M_2", pool_size=2, strides=2),

        # 2 times convolutions without max pooling.
        keras.layers.Conv2D(name="3_C", filters=40, kernel_size=(1,1), padding="same", activation="relu"),
        keras.layers.BatchNormalization(),
        keras.layers.Conv2D(name="4_C", filters=12, kernel_size=(3,3), padding="same"),
        keras.layers.BatchNormalization(),

        keras.layers.Flatten(),
        keras.layers.Dense(432, activation="relu"),
        keras.layers.Dense(60, activation="relu"),
    ])

    # Initialize optimizer.
    optimizer = keras.optimizers.Adam(learning_rate=0.001)  # Adam  optimizer.

    base_model.compile(optimizer=optimizer, loss=keras.losses.binary_crossentropy, metrics=["accuracy"],
                       sample_weight_mode=None)

    base_model.build((60, 13, 1))

    print("Base Model initialized successfully")

    return base_model

# %% [markdown]
# Build Siamese Model:

# %%
# Build a Siamese Neural Network for Automatic Speaker Verification (AVS).
def build_siamese(base_model, input_shape):

    # Set inputs to shape.
    sample1 = tf.keras.Input(shape=input_shape)
    sample2 = tf.keras.Input(shape=input_shape)

    # Get feature maps by samples from NNW model.
    encoded_sample1 = base_model(sample1)
    encoded_sample2 = base_model(sample2)

    # Calculate euclidean distance.
    euclidean_dist = Subtract()([encoded_sample1, encoded_sample2])
    euclidean_dist = Lambda(lambda x: K.sqrt(K.mean(K.square(x), axis=-1, keepdims=True)))(euclidean_dist)

    # Output single sigmoidian number defining if two sample utterances were from same speaker (~1 = same, ~0 = different).
    prediction = keras.layers.Dense(1, activation="sigmoid")(euclidean_dist)

    siamese_model = Model(inputs=[sample1, sample2], outputs=prediction)

    # Initialize optimizer.
    optimizer = keras.optimizers.Adam(learning_rate=0.001)  # Adam optimizer.

    siamese_model.compile(optimizer = optimizer, loss = keras.losses.binary_crossentropy, metrics = ["accuracy"], sample_weight_mode=None)

    siamese_model.build((120, 26, 1))

    print("Siamese model build succesfully")

    return siamese_model

# %% [markdown]
# Function to fit the Model:

# %%
# Trains the given Siamese Model with given Train Set.
def train_siamese(train_samples: pd.DataFrame, siamese_model: Model = None, verbose: bool = False):

    # Get indices from Sample Set.
    indices = np.arange(len(train_samples))
    np.random.shuffle(indices)
    indices_clone = np.copy(indices)
    np.random.shuffle(indices_clone)

    # Generate Sample Set as pairwise DataFrame based on indices.
    pairwise_map = pd.DataFrame({"sample1": indices, "sample2": indices_clone})

    # Take speakers from Sample Set.
    speaker_sample1 = train_samples["spk"].iloc[pairwise_map["sample1"].values].values
    speaker_sample2 = train_samples["spk"].iloc[pairwise_map["sample2"].values].values

    # Take MFCCs for Sample Set.
    mfccs_1 = train_samples["mfcc"].iloc[speaker_sample1].values
    mfccs_2 = train_samples["mfcc"].iloc[speaker_sample2].values

    # Generate correct input format for NNW.
    mfccs_inputs_1 = np.zeros((len(train_samples), 60, 13))
    mfccs_inputs_2 = np.zeros((len(train_samples), 60, 13))
    for i in range(len(train_samples)):
        mfccs_inputs_1[i,:] = mfccs_1[i]
        mfccs_inputs_2[i,:] = mfccs_2[i]

    # Sanity checks.
    print(mfccs_inputs_1.shape)
    print(mfccs_inputs_2.shape)

    # Reshape.
    mfccs_inputs_1 = mfccs_inputs_1.reshape((-1, 60, 13, 1))
    mfccs_inputs_2 = mfccs_inputs_2.reshape((-1, 60, 13, 1))

    # Check if same speaker.
    y = np.equal(speaker_sample1, speaker_sample2)

    # Get sum of how many speakers were same and adjust weigths.
    weight_zero = int(np.sum(y))/int(len(train_samples)-np.sum(y)) # For not same speaker 0s.
    weight_one = 1 # For same speaker 1s.

    # Define batch size.
    batch_size = len(mfccs_inputs_1)//40

    # If Model is passed, dont build new.
    if siamese_model == None:
        # Build Base Model.
        base_model = build_model()

        # Build Siamese NNW.
        siamese_model = build_siamese(base_model,(60,13,1))

    # If verbose is true, print Model summaries.
    if verbose == True:
        base_model.summary()
        siamese_model.summary()

    # Feed MFCC features from samples to Siamese NNW and train it based on
    # if utterances were from same or not same person.

    # Train Model.
    siamese_model.fit(x=[mfccs_inputs_1, mfccs_inputs_2], y=y,
                      validation_split=0.2, batch_size=batch_size,
                      epochs=100, shuffle=True, verbose=2, class_weight={0: weight_zero, 1: weight_one})

    # Return trained Model.
    return siamese_model

# %%
# Generate Siamese Models and train them for each set (to be evaluated later). 
# To see Model summaries, set verbose=True (not set true for first Model to see the summary).
siamese_model_basic = train_siamese(train_set_basic, verbose=True)
# Out:
# (20000, 60, 13)
# (20000, 60, 13)
# Base Model initialized successfully
# Siamese model build succesfully
# Model: "sequential_49"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# 1_C (Conv2D)                 (None, 60, 13, 32)        832
# _________________________________________________________________
# batch_normalization_196 (Bat (None, 60, 13, 32)        128
# _________________________________________________________________
# M_1 (MaxPooling2D)           (None, 30, 6, 32)         0
# _________________________________________________________________
# 2_C (Conv2D)                 (None, 30, 6, 40)         32040
# _________________________________________________________________
# batch_normalization_197 (Bat (None, 30, 6, 40)         160
# _________________________________________________________________
# M_2 (MaxPooling2D)           (None, 15, 3, 40)         0
# _________________________________________________________________
# 3_C (Conv2D)                 (None, 15, 3, 40)         1640
# _________________________________________________________________
# batch_normalization_198 (Bat (None, 15, 3, 40)         160
# _________________________________________________________________
# 4_C (Conv2D)                 (None, 15, 3, 12)         4332
# _________________________________________________________________
# batch_normalization_199 (Bat (None, 15, 3, 12)         48
# _________________________________________________________________
# flatten_49 (Flatten)         (None, 540)               0
# _________________________________________________________________
# dense_147 (Dense)            (None, 432)               233712
# _________________________________________________________________
# dense_148 (Dense)            (None, 60)                25980
# =================================================================
# Total params: 299,032
# Trainable params: 298,784
# Non-trainable params: 248
# _________________________________________________________________
# Model: "functional_99"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_99 (InputLayer)           [(None, 60, 13, 1)]  0
# __________________________________________________________________________________________________
# input_100 (InputLayer)          [(None, 60, 13, 1)]  0
# __________________________________________________________________________________________________
# sequential_49 (Sequential)      (None, 60)           299032      input_99[0][0]
#                                                                  input_100[0][0]
# __________________________________________________________________________________________________
# subtract_49 (Subtract)          (None, 60)           0           sequential_49[0][0]
#                                                                  sequential_49[1][0]
# __________________________________________________________________________________________________
# lambda_49 (Lambda)              (None, 1)            0           subtract_49[0][0]
# __________________________________________________________________________________________________
# dense_149 (Dense)               (None, 1)            2           lambda_49[0][0]
# ==================================================================================================
# Total params: 299,034
# Trainable params: 298,786
# Non-trainable params: 248
# __________________________________________________________________________________________________
# Epoch 1/100
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0114s vs `on_train_batch_end` time: 0.0635s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0060s vs `on_test_batch_end` time: 0.0230s). Check your callbacks.
# 32/32 - 3s - loss: 0.0197 - accuracy: 0.9823 - val_loss: 0.4734 - val_accuracy: 1.0000
# Epoch 2/100
# 32/32 - 3s - loss: 0.0163 - accuracy: 0.9931 - val_loss: 0.2552 - val_accuracy: 1.0000
# Epoch 3/100
# 32/32 - 3s - loss: 0.0158 - accuracy: 0.9982 - val_loss: 0.1001 - val_accuracy: 1.0000
# Epoch 4/100
# 32/32 - 3s - loss: 0.0153 - accuracy: 0.9998 - val_loss: 0.0677 - val_accuracy: 1.0000
# Epoch 5/100
# 32/32 - 3s - loss: 0.0149 - accuracy: 0.9999 - val_loss: 0.0348 - val_accuracy: 1.0000
# Epoch 6/100
# 32/32 - 3s - loss: 0.0145 - accuracy: 1.0000 - val_loss: 0.0255 - val_accuracy: 1.0000
# Epoch 7/100
# 32/32 - 3s - loss: 0.0142 - accuracy: 1.0000 - val_loss: 0.0240 - val_accuracy: 1.0000
# Epoch 8/100
# 32/32 - 3s - loss: 0.0139 - accuracy: 1.0000 - val_loss: 0.0181 - val_accuracy: 1.0000
# Epoch 9/100
# 32/32 - 3s - loss: 0.0135 - accuracy: 1.0000 - val_loss: 0.0169 - val_accuracy: 1.0000
# Epoch 10/100
# 32/32 - 3s - loss: 0.0132 - accuracy: 1.0000 - val_loss: 0.0148 - val_accuracy: 1.0000
# Epoch 11/100
# 32/32 - 3s - loss: 0.0129 - accuracy: 1.0000 - val_loss: 0.0149 - val_accuracy: 1.0000
# Epoch 12/100
# 32/32 - 3s - loss: 0.0126 - accuracy: 1.0000 - val_loss: 0.0138 - val_accuracy: 1.0000
# Epoch 13/100
# 32/32 - 3s - loss: 0.0123 - accuracy: 1.0000 - val_loss: 0.0133 - val_accuracy: 1.0000
# Epoch 14/100
# 32/32 - 3s - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.0138 - val_accuracy: 1.0000
# Epoch 15/100
# 32/32 - 3s - loss: 0.0118 - accuracy: 1.0000 - val_loss: 0.0130 - val_accuracy: 1.0000
# Epoch 16/100
# 32/32 - 3s - loss: 0.0115 - accuracy: 1.0000 - val_loss: 0.0125 - val_accuracy: 1.0000
# Epoch 17/100
# 32/32 - 3s - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.0122 - val_accuracy: 1.0000
# Epoch 18/100
# 32/32 - 3s - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.0123 - val_accuracy: 1.0000
# Epoch 19/100
# 32/32 - 3s - loss: 0.0107 - accuracy: 1.0000 - val_loss: 0.0118 - val_accuracy: 1.0000
# Epoch 20/100
# 32/32 - 3s - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 1.0000
# Epoch 21/100
# 32/32 - 3s - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 1.0000
# Epoch 22/100
# 32/32 - 3s - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.0108 - val_accuracy: 1.0000
# Epoch 23/100
# 32/32 - 3s - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.0105 - val_accuracy: 1.0000
# Epoch 24/100
# 32/32 - 3s - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.0106 - val_accuracy: 1.0000
# Epoch 25/100
# 32/32 - 3s - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.0101 - val_accuracy: 1.0000
# Epoch 26/100
# 32/32 - 3s - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.0098 - val_accuracy: 1.0000
# Epoch 27/100
# 32/32 - 3s - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.0097 - val_accuracy: 1.0000
# Epoch 28/100
# 32/32 - 3s - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.0095 - val_accuracy: 1.0000
# Epoch 29/100
# 32/32 - 3s - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.0094 - val_accuracy: 1.0000
# Epoch 30/100
# 32/32 - 3s - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.0094 - val_accuracy: 1.0000
# Epoch 31/100
# 32/32 - 3s - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.0089 - val_accuracy: 1.0000
# Epoch 32/100
# 32/32 - 3s - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.0087 - val_accuracy: 1.0000
# Epoch 33/100
# 32/32 - 3s - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 34/100
# 32/32 - 3s - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.0083 - val_accuracy: 1.0000
# Epoch 35/100
# 32/32 - 3s - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 1.0000
# Epoch 36/100
# 32/32 - 3s - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 1.0000
# Epoch 37/100
# 32/32 - 3s - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 1.0000
# Epoch 38/100
# 32/32 - 3s - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.0076 - val_accuracy: 1.0000
# Epoch 39/100
# 32/32 - 3s - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.0076 - val_accuracy: 1.0000
# Epoch 40/100
# 32/32 - 3s - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 1.0000
# Epoch 41/100
# 32/32 - 3s - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 1.0000
# Epoch 42/100
# 32/32 - 3s - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.0071 - val_accuracy: 1.0000
# Epoch 43/100
# 32/32 - 3s - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.0069 - val_accuracy: 1.0000
# Epoch 44/100
# 32/32 - 3s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.0068 - val_accuracy: 1.0000
# Epoch 45/100
# 32/32 - 3s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0067 - val_accuracy: 1.0000
# Epoch 46/100
# 32/32 - 3s - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 1.0000
# Epoch 47/100
# 32/32 - 3s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 48/100
# 32/32 - 3s - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 1.0000
# Epoch 49/100
# 32/32 - 3s - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.0062 - val_accuracy: 1.0000
# Epoch 50/100
# 32/32 - 3s - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.0060 - val_accuracy: 1.0000
# Epoch 51/100
# 32/32 - 3s - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.0061 - val_accuracy: 1.0000
# Epoch 52/100
# 32/32 - 3s - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.0058 - val_accuracy: 1.0000
# Epoch 53/100
# 32/32 - 3s - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 54/100
# 32/32 - 3s - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.0055 - val_accuracy: 1.0000
# Epoch 55/100
# 32/32 - 3s - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.0054 - val_accuracy: 1.0000
# Epoch 56/100
# 32/32 - 3s - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0053 - val_accuracy: 1.0000
# Epoch 57/100
# 32/32 - 3s - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.0053 - val_accuracy: 1.0000
# Epoch 58/100
# 32/32 - 3s - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.0052 - val_accuracy: 1.0000
# Epoch 59/100
# 32/32 - 3s - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.0051 - val_accuracy: 1.0000
# Epoch 60/100
# 32/32 - 3s - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.0050 - val_accuracy: 1.0000
# Epoch 61/100
# 32/32 - 3s - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 62/100
# 32/32 - 3s - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 63/100
# 32/32 - 3s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 64/100
# 32/32 - 3s - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 65/100
# 32/32 - 3s - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 66/100
# 32/32 - 3s - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0044 - val_accuracy: 1.0000
# Epoch 67/100
# 32/32 - 3s - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0044 - val_accuracy: 1.0000
# Epoch 68/100
# 32/32 - 3s - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0043 - val_accuracy: 1.0000
# Epoch 69/100
# 32/32 - 3s - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 70/100
# 32/32 - 3s - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 71/100
# 32/32 - 3s - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 72/100
# 32/32 - 3s - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0040 - val_accuracy: 1.0000
# Epoch 73/100
# 32/32 - 3s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 74/100
# 32/32 - 3s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 75/100
# 32/32 - 3s - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 76/100
# 32/32 - 3s - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 77/100
# 32/32 - 3s - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 78/100
# 32/32 - 3s - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 79/100
# 32/32 - 3s - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 80/100
# 32/32 - 3s - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 81/100
# 32/32 - 3s - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 82/100
# 32/32 - 3s - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 83/100
# 32/32 - 3s - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 84/100
# 32/32 - 3s - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 85/100
# 32/32 - 3s - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 86/100
# 32/32 - 3s - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 87/100
# 32/32 - 3s - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 88/100
# 32/32 - 3s - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 89/100
# 32/32 - 3s - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 90/100
# 32/32 - 3s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 91/100
# 32/32 - 3s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 92/100
# 32/32 - 3s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 93/100
# 32/32 - 3s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 94/100
# 32/32 - 3s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 95/100
# 32/32 - 3s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 96/100
# 32/32 - 3s - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 97/100
# 32/32 - 3s - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 98/100
# 32/32 - 3s - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 99/100
# 32/32 - 3s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 100/100
# 32/32 - 3s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000

# %%
siamese_model_dependent = train_siamese(train_set_dependent, verbose=False)
# Out:
# (1500, 60, 13)
# (1500, 60, 13)
# Base Model initialized successfully
# Siamese model build succesfully
# Epoch 1/100
# 33/33 - 1s - loss: 0.0153 - accuracy: 0.9817 - val_loss: 0.4466 - val_accuracy: 1.0000
# Epoch 2/100
# 33/33 - 0s - loss: 0.0143 - accuracy: 0.9817 - val_loss: 0.3245 - val_accuracy: 1.0000
# Epoch 3/100
# 33/33 - 0s - loss: 0.0140 - accuracy: 0.9817 - val_loss: 0.1682 - val_accuracy: 1.0000
# Epoch 4/100
# 33/33 - 0s - loss: 0.0135 - accuracy: 0.9858 - val_loss: 0.0849 - val_accuracy: 1.0000
# Epoch 5/100
# 33/33 - 0s - loss: 0.0128 - accuracy: 0.9933 - val_loss: 0.0527 - val_accuracy: 1.0000
# Epoch 6/100
# 33/33 - 0s - loss: 0.0130 - accuracy: 0.9917 - val_loss: 0.0352 - val_accuracy: 1.0000
# Epoch 7/100
# 33/33 - 0s - loss: 0.0125 - accuracy: 0.9983 - val_loss: 0.0297 - val_accuracy: 1.0000
# Epoch 8/100
# 33/33 - 0s - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.0193 - val_accuracy: 1.0000
# Epoch 9/100
# 33/33 - 0s - loss: 0.0123 - accuracy: 0.9983 - val_loss: 0.0192 - val_accuracy: 1.0000
# Epoch 10/100
# 33/33 - 0s - loss: 0.0118 - accuracy: 1.0000 - val_loss: 0.0156 - val_accuracy: 1.0000
# Epoch 11/100
# 33/33 - 0s - loss: 0.0117 - accuracy: 1.0000 - val_loss: 0.0130 - val_accuracy: 1.0000
# Epoch 12/100
# 33/33 - 0s - loss: 0.0114 - accuracy: 1.0000 - val_loss: 0.0139 - val_accuracy: 1.0000
# Epoch 13/100
# 33/33 - 0s - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.0155 - val_accuracy: 1.0000
# Epoch 14/100
# 33/33 - 0s - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.0135 - val_accuracy: 1.0000
# Epoch 15/100
# 33/33 - 0s - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.0123 - val_accuracy: 1.0000
# Epoch 16/100
# 33/33 - 0s - loss: 0.0108 - accuracy: 1.0000 - val_loss: 0.0135 - val_accuracy: 1.0000
# Epoch 17/100
# 33/33 - 0s - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.0123 - val_accuracy: 1.0000
# Epoch 18/100
# 33/33 - 0s - loss: 0.0106 - accuracy: 0.9992 - val_loss: 0.0139 - val_accuracy: 1.0000
# Epoch 19/100
# 33/33 - 0s - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.0125 - val_accuracy: 1.0000
# Epoch 20/100
# 33/33 - 0s - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.0138 - val_accuracy: 1.0000
# Epoch 21/100
# 33/33 - 0s - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.0174 - val_accuracy: 1.0000
# Epoch 22/100
# 33/33 - 0s - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.0172 - val_accuracy: 1.0000
# Epoch 23/100
# 33/33 - 0s - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.0145 - val_accuracy: 1.0000
# Epoch 24/100
# 33/33 - 0s - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.0146 - val_accuracy: 1.0000
# Epoch 25/100
# 33/33 - 0s - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.0141 - val_accuracy: 1.0000
# Epoch 26/100
# 33/33 - 0s - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.0150 - val_accuracy: 1.0000
# Epoch 27/100
# 33/33 - 0s - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.0149 - val_accuracy: 1.0000
# Epoch 28/100
# 33/33 - 0s - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.0117 - val_accuracy: 1.0000
# Epoch 29/100
# 33/33 - 0s - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.0137 - val_accuracy: 1.0000
# Epoch 30/100
# 33/33 - 0s - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.0116 - val_accuracy: 1.0000
# Epoch 31/100
# 33/33 - 0s - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.0104 - val_accuracy: 1.0000
# Epoch 32/100
# 33/33 - 0s - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 1.0000
# Epoch 33/100
# 33/33 - 0s - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.0154 - val_accuracy: 1.0000
# Epoch 34/100
# 33/33 - 0s - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.0133 - val_accuracy: 1.0000
# Epoch 35/100
# 33/33 - 0s - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.0119 - val_accuracy: 1.0000
# Epoch 36/100
# 33/33 - 0s - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.0099 - val_accuracy: 1.0000
# Epoch 37/100
# 33/33 - 0s - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.0108 - val_accuracy: 1.0000
# Epoch 38/100
# 33/33 - 0s - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.0092 - val_accuracy: 1.0000
# Epoch 39/100
# 33/33 - 0s - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.0097 - val_accuracy: 1.0000
# Epoch 40/100
# 33/33 - 0s - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.0108 - val_accuracy: 1.0000
# Epoch 41/100
# 33/33 - 0s - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.0100 - val_accuracy: 1.0000
# Epoch 42/100
# 33/33 - 0s - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.0132 - val_accuracy: 1.0000
# Epoch 43/100
# 33/33 - 0s - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.0104 - val_accuracy: 1.0000
# Epoch 44/100
# 33/33 - 0s - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.0129 - val_accuracy: 1.0000
# Epoch 45/100
# 33/33 - 0s - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.0124 - val_accuracy: 1.0000
# Epoch 46/100
# 33/33 - 0s - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 1.0000
# Epoch 47/100
# 33/33 - 0s - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 1.0000
# Epoch 48/100
# 33/33 - 0s - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.0106 - val_accuracy: 1.0000
# Epoch 49/100
# 33/33 - 0s - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.0105 - val_accuracy: 1.0000
# Epoch 50/100
# 33/33 - 0s - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.0103 - val_accuracy: 1.0000
# Epoch 51/100
# 33/33 - 0s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.0098 - val_accuracy: 1.0000
# Epoch 52/100
# 33/33 - 0s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.0095 - val_accuracy: 1.0000
# Epoch 53/100
# 33/33 - 0s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 1.0000
# Epoch 54/100
# 33/33 - 0s - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.0097 - val_accuracy: 1.0000
# Epoch 55/100
# 33/33 - 0s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0093 - val_accuracy: 1.0000
# Epoch 56/100
# 33/33 - 0s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0077 - val_accuracy: 1.0000
# Epoch 57/100
# 33/33 - 0s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0088 - val_accuracy: 1.0000
# Epoch 58/100
# 33/33 - 0s - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0095 - val_accuracy: 1.0000
# Epoch 59/100
# 33/33 - 0s - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0089 - val_accuracy: 1.0000
# Epoch 60/100
# 33/33 - 0s - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.0093 - val_accuracy: 1.0000
# Epoch 61/100
# 33/33 - 0s - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.0124 - val_accuracy: 1.0000
# Epoch 62/100
# 33/33 - 0s - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.0108 - val_accuracy: 1.0000
# Epoch 63/100
# 33/33 - 0s - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.0088 - val_accuracy: 1.0000
# Epoch 64/100
# 33/33 - 0s - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 1.0000
# Epoch 65/100
# 33/33 - 0s - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 1.0000
# Epoch 66/100
# 33/33 - 0s - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 67/100
# 33/33 - 0s - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.0088 - val_accuracy: 1.0000
# Epoch 68/100
# 33/33 - 0s - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 1.0000
# Epoch 69/100
# 33/33 - 0s - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.0067 - val_accuracy: 1.0000
# Epoch 70/100
# 33/33 - 0s - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.0076 - val_accuracy: 1.0000
# Epoch 71/100
# 33/33 - 0s - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.0083 - val_accuracy: 1.0000
# Epoch 72/100
# 33/33 - 0s - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.0069 - val_accuracy: 1.0000
# Epoch 73/100
# 33/33 - 0s - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.0154 - val_accuracy: 1.0000
# Epoch 74/100
# 33/33 - 0s - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.0076 - val_accuracy: 1.0000
# Epoch 75/100
# 33/33 - 0s - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 1.0000
# Epoch 76/100
# 33/33 - 0s - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.0093 - val_accuracy: 1.0000
# Epoch 77/100
# 33/33 - 0s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 1.0000
# Epoch 78/100
# 33/33 - 0s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 1.0000
# Epoch 79/100
# 33/33 - 0s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.0103 - val_accuracy: 1.0000
# Epoch 80/100
# 33/33 - 0s - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.0076 - val_accuracy: 1.0000
# Epoch 81/100
# 33/33 - 0s - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.0092 - val_accuracy: 1.0000
# Epoch 82/100
# 33/33 - 0s - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0077 - val_accuracy: 1.0000
# Epoch 83/100
# 33/33 - 0s - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0070 - val_accuracy: 1.0000
# Epoch 84/100
# 33/33 - 0s - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0062 - val_accuracy: 1.0000
# Epoch 85/100
# 33/33 - 0s - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 86/100
# 33/33 - 0s - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.0060 - val_accuracy: 1.0000
# Epoch 87/100
# 33/33 - 0s - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 1.0000
# Epoch 88/100
# 33/33 - 0s - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 89/100
# 33/33 - 0s - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0060 - val_accuracy: 1.0000
# Epoch 90/100
# 33/33 - 0s - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0059 - val_accuracy: 1.0000
# Epoch 91/100
# 33/33 - 0s - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0070 - val_accuracy: 1.0000
# Epoch 92/100
# 33/33 - 0s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0070 - val_accuracy: 1.0000
# Epoch 93/100
# 33/33 - 0s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 94/100
# 33/33 - 0s - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 1.0000
# Epoch 95/100
# 33/33 - 0s - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 1.0000
# Epoch 96/100
# 33/33 - 0s - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0069 - val_accuracy: 1.0000
# Epoch 97/100
# 33/33 - 0s - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0071 - val_accuracy: 1.0000
# Epoch 98/100
# 33/33 - 0s - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 99/100
# 33/33 - 0s - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0076 - val_accuracy: 1.0000
# Epoch 100/100
# 33/33 - 0s - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 1.0000

# %%
siamese_model_limited = train_siamese(train_set_limited, verbose=False)
# Out:
# (15000, 60, 13)
# (15000, 60, 13)
# Base Model initialized successfully
# Siamese model build succesfully
# Epoch 1/100
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0088s vs `on_train_batch_end` time: 0.0719s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0053s vs `on_test_batch_end` time: 0.0169s). Check your callbacks.
# 32/32 - 3s - loss: 0.0133 - accuracy: 0.9832 - val_loss: 0.4569 - val_accuracy: 1.0000
# Epoch 2/100
# 32/32 - 2s - loss: 0.0120 - accuracy: 0.9947 - val_loss: 0.2068 - val_accuracy: 1.0000
# Epoch 3/100
# 32/32 - 2s - loss: 0.0116 - accuracy: 0.9995 - val_loss: 0.1057 - val_accuracy: 1.0000
# Epoch 4/100
# 32/32 - 2s - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.0525 - val_accuracy: 1.0000
# Epoch 5/100
# 32/32 - 2s - loss: 0.0111 - accuracy: 0.9999 - val_loss: 0.0259 - val_accuracy: 1.0000
# Epoch 6/100
# 32/32 - 2s - loss: 0.0108 - accuracy: 1.0000 - val_loss: 0.0192 - val_accuracy: 1.0000
# Epoch 7/100
# 32/32 - 2s - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.0152 - val_accuracy: 1.0000
# Epoch 8/100
# 32/32 - 2s - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.0123 - val_accuracy: 1.0000
# Epoch 9/100
# 32/32 - 2s - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.0116 - val_accuracy: 1.0000
# Epoch 10/100
# 32/32 - 2s - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 1.0000
# Epoch 11/100
# 32/32 - 2s - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.0106 - val_accuracy: 1.0000
# Epoch 12/100
# 32/32 - 2s - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.0103 - val_accuracy: 1.0000
# Epoch 13/100
# 32/32 - 2s - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.0099 - val_accuracy: 1.0000
# Epoch 14/100
# 32/32 - 2s - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.0095 - val_accuracy: 1.0000
# Epoch 15/100
# 32/32 - 2s - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 1.0000
# Epoch 16/100
# 32/32 - 2s - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.0094 - val_accuracy: 1.0000
# Epoch 17/100
# 32/32 - 2s - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.0090 - val_accuracy: 1.0000
# Epoch 18/100
# 32/32 - 2s - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.0097 - val_accuracy: 1.0000
# Epoch 19/100
# 32/32 - 2s - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.0091 - val_accuracy: 1.0000
# Epoch 20/100
# 32/32 - 2s - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 1.0000
# Epoch 21/100
# 32/32 - 2s - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 22/100
# 32/32 - 2s - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.0083 - val_accuracy: 1.0000
# Epoch 23/100
# 32/32 - 2s - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.0083 - val_accuracy: 1.0000
# Epoch 24/100
# 32/32 - 2s - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.0077 - val_accuracy: 1.0000
# Epoch 25/100
# 32/32 - 2s - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.0077 - val_accuracy: 1.0000
# Epoch 26/100
# 32/32 - 2s - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 27/100
# 32/32 - 2s - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 1.0000
# Epoch 28/100
# 32/32 - 2s - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 1.0000
# Epoch 29/100
# 32/32 - 2s - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.0071 - val_accuracy: 1.0000
# Epoch 30/100
# 32/32 - 2s - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 1.0000
# Epoch 31/100
# 32/32 - 2s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0068 - val_accuracy: 1.0000
# Epoch 32/100
# 32/32 - 2s - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 1.0000
# Epoch 33/100
# 32/32 - 2s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0067 - val_accuracy: 1.0000
# Epoch 34/100
# 32/32 - 2s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 1.0000
# Epoch 35/100
# 32/32 - 2s - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 36/100
# 32/32 - 2s - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.0062 - val_accuracy: 1.0000
# Epoch 37/100
# 32/32 - 2s - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.0059 - val_accuracy: 1.0000
# Epoch 38/100
# 32/32 - 2s - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.0059 - val_accuracy: 1.0000
# Epoch 39/100
# 32/32 - 2s - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.0058 - val_accuracy: 1.0000
# Epoch 40/100
# 32/32 - 2s - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 41/100
# 32/32 - 2s - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 42/100
# 32/32 - 2s - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0054 - val_accuracy: 1.0000
# Epoch 43/100
# 32/32 - 2s - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.0052 - val_accuracy: 1.0000
# Epoch 44/100
# 32/32 - 2s - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.0052 - val_accuracy: 1.0000
# Epoch 45/100
# 32/32 - 2s - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 46/100
# 32/32 - 2s - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.0050 - val_accuracy: 1.0000
# Epoch 47/100
# 32/32 - 2s - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 48/100
# 32/32 - 2s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.0050 - val_accuracy: 1.0000
# Epoch 49/100
# 32/32 - 2s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 50/100
# 32/32 - 2s - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 51/100
# 32/32 - 2s - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 52/100
# 32/32 - 2s - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 53/100
# 32/32 - 2s - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0043 - val_accuracy: 1.0000
# Epoch 54/100
# 32/32 - 2s - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 55/100
# 32/32 - 2s - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 56/100
# 32/32 - 2s - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 57/100
# 32/32 - 2s - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0044 - val_accuracy: 1.0000
# Epoch 58/100
# 32/32 - 2s - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 59/100
# 32/32 - 2s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0040 - val_accuracy: 1.0000
# Epoch 60/100
# 32/32 - 2s - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 61/100
# 32/32 - 2s - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 62/100
# 32/32 - 2s - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 63/100
# 32/32 - 2s - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 64/100
# 32/32 - 2s - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 65/100
# 32/32 - 2s - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 66/100
# 32/32 - 2s - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 67/100
# 32/32 - 2s - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 68/100
# 32/32 - 2s - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 69/100
# 32/32 - 2s - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 70/100
# 32/32 - 2s - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 71/100
# 32/32 - 2s - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 72/100
# 32/32 - 2s - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 73/100
# 32/32 - 2s - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 74/100
# 32/32 - 2s - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 75/100
# 32/32 - 2s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 76/100
# 32/32 - 2s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 77/100
# 32/32 - 2s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 78/100
# 32/32 - 2s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 79/100
# 32/32 - 2s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 80/100
# 32/32 - 2s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 81/100
# 32/32 - 2s - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 82/100
# 32/32 - 2s - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 83/100
# 32/32 - 2s - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 84/100
# 32/32 - 2s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 85/100
# 32/32 - 2s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 86/100
# 32/32 - 2s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 87/100
# 32/32 - 2s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 88/100
# 32/32 - 2s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 89/100
# 32/32 - 2s - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 90/100
# 32/32 - 2s - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 91/100
# 32/32 - 2s - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 92/100
# 32/32 - 2s - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 93/100
# 32/32 - 2s - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 94/100
# 32/32 - 2s - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 95/100
# 32/32 - 2s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 96/100
# 32/32 - 2s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 97/100
# 32/32 - 2s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 98/100
# 32/32 - 2s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 99/100
# 32/32 - 2s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 100/100
# 32/32 - 2s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000

# %%
siamese_model_independent = train_siamese(train_set_independent, verbose=False)
# Out:
# (15000, 60, 13)
# (15000, 60, 13)
# Base Model initialized successfully
# Siamese model build succesfully
# Epoch 1/100
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0082s vs `on_train_batch_end` time: 0.0740s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0058s vs `on_test_batch_end` time: 0.0165s). Check your callbacks.
# 32/32 - 2s - loss: 0.0167 - accuracy: 0.9827 - val_loss: 0.4536 - val_accuracy: 1.0000
# Epoch 2/100
# 32/32 - 2s - loss: 0.0125 - accuracy: 0.9895 - val_loss: 0.1775 - val_accuracy: 1.0000
# Epoch 3/100
# 32/32 - 2s - loss: 0.0121 - accuracy: 0.9961 - val_loss: 0.0753 - val_accuracy: 1.0000
# Epoch 4/100
# 32/32 - 2s - loss: 0.0118 - accuracy: 0.9986 - val_loss: 0.0426 - val_accuracy: 1.0000
# Epoch 5/100
# 32/32 - 2s - loss: 0.0114 - accuracy: 0.9995 - val_loss: 0.0318 - val_accuracy: 1.0000
# Epoch 6/100
# 32/32 - 2s - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.0221 - val_accuracy: 1.0000
# Epoch 7/100
# 32/32 - 2s - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.0185 - val_accuracy: 1.0000
# Epoch 8/100
# 32/32 - 2s - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.0147 - val_accuracy: 1.0000
# Epoch 9/100
# 32/32 - 2s - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.0147 - val_accuracy: 1.0000
# Epoch 10/100
# 32/32 - 2s - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.0138 - val_accuracy: 1.0000
# Epoch 11/100
# 32/32 - 2s - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.0127 - val_accuracy: 1.0000
# Epoch 12/100
# 32/32 - 2s - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.0124 - val_accuracy: 1.0000
# Epoch 13/100
# 32/32 - 2s - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.0117 - val_accuracy: 1.0000
# Epoch 14/100
# 32/32 - 2s - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.0117 - val_accuracy: 1.0000
# Epoch 15/100
# 32/32 - 2s - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.0122 - val_accuracy: 1.0000
# Epoch 16/100
# 32/32 - 2s - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.0117 - val_accuracy: 1.0000
# Epoch 17/100
# 32/32 - 2s - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.0110 - val_accuracy: 1.0000
# Epoch 18/100
# 32/32 - 2s - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.0107 - val_accuracy: 1.0000
# Epoch 19/100
# 32/32 - 2s - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.0101 - val_accuracy: 1.0000
# Epoch 20/100
# 32/32 - 2s - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.0099 - val_accuracy: 1.0000
# Epoch 21/100
# 32/32 - 2s - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.0106 - val_accuracy: 1.0000
# Epoch 22/100
# 32/32 - 2s - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.0098 - val_accuracy: 1.0000
# Epoch 23/100
# 32/32 - 2s - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.0091 - val_accuracy: 1.0000
# Epoch 24/100
# 32/32 - 2s - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.0094 - val_accuracy: 1.0000
# Epoch 25/100
# 32/32 - 2s - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.0089 - val_accuracy: 1.0000
# Epoch 26/100
# 32/32 - 2s - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 27/100
# 32/32 - 2s - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 1.0000
# Epoch 28/100
# 32/32 - 2s - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 1.0000
# Epoch 29/100
# 32/32 - 2s - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 1.0000
# Epoch 30/100
# 32/32 - 2s - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 1.0000
# Epoch 31/100
# 32/32 - 2s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 1.0000
# Epoch 32/100
# 32/32 - 2s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0077 - val_accuracy: 1.0000
# Epoch 33/100
# 32/32 - 2s - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.0075 - val_accuracy: 1.0000
# Epoch 34/100
# 32/32 - 2s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 1.0000
# Epoch 35/100
# 32/32 - 2s - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0070 - val_accuracy: 1.0000
# Epoch 36/100
# 32/32 - 2s - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.0071 - val_accuracy: 1.0000
# Epoch 37/100
# 32/32 - 2s - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.0069 - val_accuracy: 1.0000
# Epoch 38/100
# 32/32 - 2s - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.0067 - val_accuracy: 1.0000
# Epoch 39/100
# 32/32 - 2s - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 1.0000
# Epoch 40/100
# 32/32 - 2s - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 1.0000
# Epoch 41/100
# 32/32 - 2s - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.0062 - val_accuracy: 1.0000
# Epoch 42/100
# 32/32 - 2s - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 1.0000
# Epoch 43/100
# 32/32 - 2s - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 1.0000
# Epoch 44/100
# 32/32 - 2s - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.0062 - val_accuracy: 1.0000
# Epoch 45/100
# 32/32 - 2s - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.0061 - val_accuracy: 1.0000
# Epoch 46/100
# 32/32 - 2s - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.0058 - val_accuracy: 1.0000
# Epoch 47/100
# 32/32 - 2s - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.0056 - val_accuracy: 1.0000
# Epoch 48/100
# 32/32 - 2s - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 49/100
# 32/32 - 2s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.0054 - val_accuracy: 1.0000
# Epoch 50/100
# 32/32 - 2s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.0052 - val_accuracy: 1.0000
# Epoch 51/100
# 32/32 - 2s - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0051 - val_accuracy: 1.0000
# Epoch 52/100
# 32/32 - 2s - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.0050 - val_accuracy: 1.0000
# Epoch 53/100
# 32/32 - 2s - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 54/100
# 32/32 - 2s - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 55/100
# 32/32 - 2s - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 56/100
# 32/32 - 2s - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 57/100
# 32/32 - 2s - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 58/100
# 32/32 - 2s - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 59/100
# 32/32 - 2s - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0044 - val_accuracy: 1.0000
# Epoch 60/100
# 32/32 - 2s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0044 - val_accuracy: 1.0000
# Epoch 61/100
# 32/32 - 2s - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0044 - val_accuracy: 1.0000
# Epoch 62/100
# 32/32 - 2s - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 63/100
# 32/32 - 2s - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 64/100
# 32/32 - 2s - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0040 - val_accuracy: 1.0000
# Epoch 65/100
# 32/32 - 2s - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0040 - val_accuracy: 1.0000
# Epoch 66/100
# 32/32 - 2s - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 67/100
# 32/32 - 2s - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 68/100
# 32/32 - 2s - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 69/100
# 32/32 - 2s - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 70/100
# 32/32 - 2s - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 71/100
# 32/32 - 2s - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 72/100
# 32/32 - 2s - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 73/100
# 32/32 - 2s - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 74/100
# 32/32 - 2s - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 75/100
# 32/32 - 2s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 76/100
# 32/32 - 2s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 77/100
# 32/32 - 2s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 78/100
# 32/32 - 2s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 79/100
# 32/32 - 2s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 80/100
# 32/32 - 2s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 81/100
# 32/32 - 2s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 82/100
# 32/32 - 2s - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 83/100
# 32/32 - 2s - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 84/100
# 32/32 - 2s - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 85/100
# 32/32 - 2s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 86/100
# 32/32 - 2s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 87/100
# 32/32 - 2s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 88/100
# 32/32 - 2s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 89/100
# 32/32 - 2s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 90/100
# 32/32 - 2s - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 91/100
# 32/32 - 2s - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 92/100
# 32/32 - 2s - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 93/100
# 32/32 - 2s - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 94/100
# 32/32 - 2s - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 95/100
# 32/32 - 2s - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 96/100
# 32/32 - 2s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 97/100
# 32/32 - 2s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 98/100
# 32/32 - 2s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 99/100
# 32/32 - 2s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 100/100
# 32/32 - 2s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000

# %% [markdown]
# If you want to save trained Models to runtime or Drive, run following (after mounting if Drive), change booleans:

# %%
save_temp = False
save_drive = True

if save_temp == True:
   # Save trained models.
    siamese_model_basic.save("basic_model.h5")
    siamese_model_dependent.save("dependent_model.h5")
    siamese_model_limited.save("limited_model.h5")
    siamese_model_independent.save("independent_model.h5")

if save_drive == True:
  # Save trained models to Drive.
  path = "/content/drive/MyDrive/basic_model.h5"
  siamese_model_basic.save(path)

  path = "/content/drive/MyDrive/dependent_model.h5"
  siamese_model_dependent.save(path)

  path = "/content/drive/MyDrive/limited_model.h5"
  siamese_model_limited.save(path)

  path = "/content/drive/MyDrive/independent_model.h5"
  siamese_model_independent.save(path)

# %% [markdown]
# To load Models from the runtime or Drive run this block (change booleans):

# %%
load_temp = False
load_drive = True

if load_temp == True:
  # Load trained models for re-use from runtime.
  siamese_model_basic = tf.keras.models.load_model("basic_model.h5")
  siamese_model_dependent = tf.keras.models.load_model("dependent_model.h5")
  siamese_model_limited = tf.keras.models.load_model("limited_model.h5")
  siamese_model_independent = tf.keras.models.load_model("independent_model.h5")

if load_drive == True:
  # Load trained models for re-use from Drive.
  path = "/content/drive/MyDrive/basic_model.h5"
  siamese_model_basic = tf.keras.models.load_model(path)

  path = "/content/drive/MyDrive/dependent_model.h5"
  siamese_model_dependent = tf.keras.models.load_model(path)

  path = "/content/drive/MyDrive/limited_model.h5"
  siamese_model_limited = tf.keras.models.load_model(path)

  path = "/content/drive/MyDrive/independent_model.h5"
  siamese_model_independent = tf.keras.models.load_model(path)

# %% [markdown]
# Function for fitting Model with less biased data (samples more evenly spread between same / not same speakers):

# %%
def train_siamese_equal(train_samples: pd.DataFrame, siamese_model: Model = None, verbose: bool = False):
  
    # Get indices from Sample Set.
    indices = np.arange(len(train_samples))
    np.random.shuffle(indices)
    indices_clone = np.copy(indices)
    np.random.shuffle(indices_clone)

    # Generate Sample Set as pairwise DataFrame based on indices.
    pairwise_map = pd.DataFrame({"sample1": indices, "sample2": indices_clone})

    # Take speakers from Sample Set.
    speaker_sample1 = train_samples["spk"].iloc[pairwise_map["sample1"].values].values
    speaker_sample2 = []

    # Take MFCCs for Sample Set.
    mfccs_1 = train_samples["mfcc"].iloc[speaker_sample1].values

    # Generate Target-scores MFCC scores for half of the utterances from same speaker for each speaker in first MFCC set.
    mfccs_2_target = []
    for i in range(len(speaker_sample1)//2):
        speaker = speaker_sample1[i]
        speaker_sample2.append(speaker)
        mfccs_speaker = train_samples.loc[train_samples["spk"] == speaker, "mfcc"]
        mfccs_target = random.sample(list(mfccs_speaker), 1)
        mfccs_2_target.append(mfccs_target)
    
    # Generate Non-target scores for the other half.
    mfccs_2_non_target = []
    for i in range(len(speaker_sample1)//2):
        speaker = speaker_sample1[i]
        not_speaker = train_samples.loc[train_samples["spk"] != speaker, "spk"].iloc[0]
        speaker_sample2.append(not_speaker)
        mfccs_not_speaker = train_samples.loc[train_samples["spk"] == not_speaker, "mfcc"]
        mfccs_non_target = random.sample(list(mfccs_not_speaker), 1)
        mfccs_2_non_target.append(mfccs_non_target)
    
    # Convert to numpy.
    speaker_sample2 = np.array(speaker_sample2)

    # Combine lists.
    mfccs_2 = mfccs_2_target + mfccs_2_non_target
    mfccs_2 = np.array(mfccs_2)
    
    # Generate correct input format for NNW.
    mfccs_inputs_1 = np.zeros((len(train_samples), 60, 13))
    mfccs_inputs_2 = np.zeros((len(train_samples), 60, 13))
    for i in range(len(train_samples)):
        mfccs_inputs_1[i,:] = mfccs_1[i]
        mfccs_inputs_2[i,:] = mfccs_2[i]

    # Sanity checks.
    print(mfccs_inputs_1.shape)
    print(mfccs_inputs_2.shape)

    # Reshape.
    mfccs_inputs_1 = mfccs_inputs_1.reshape((-1, 60, 13, 1))
    mfccs_inputs_2 = mfccs_inputs_2.reshape((-1, 60, 13, 1))

    # Check if same speaker.
    y = np.equal(speaker_sample1, speaker_sample2)

    # Get sum of how many speakers were same and adjust weigths.
    weight_zero = int(np.sum(y))/int(len(train_samples)-np.sum(y)) # For not same speaker 0s.
    weight_one = 1 # For same speaker 1s.

    # Define batch size.
    batch_size = len(mfccs_inputs_1)//40

    # If Model is passed, dont build new.
    if siamese_model == None:
        # Build Base Model.
        base_model = build_model()

        # Build Siamese NNW.
        siamese_model = build_siamese(base_model,(60,13,1))

    # If verbose is true, print Model summaries.
    if verbose == True:
        base_model.summary()
        siamese_model.summary()

    # Feed MFCC features from samples to Siamese NNW and train it based on
    # if utterances were from same or not same person.

    # Train Model.
    siamese_model.fit(x=[mfccs_inputs_1, mfccs_inputs_2], y=y,
                      validation_split=0.2, batch_size=batch_size,
                      epochs=50, shuffle=True, verbose=2, class_weight={0: weight_zero, 1: weight_one})

    # Return trained Model.
    return siamese_model

# %%
# Generate Siamese Models and train them for each set (to be evaluated later). 
# To see Model summaries, set verbose=True (not set true for first Model to see the summary).
siamese_model_basic_equal = train_siamese_equal(train_set_basic, verbose=True)
# Out:
# (20000, 60, 13)
# (20000, 60, 13)
# Base Model initialized successfully
# Siamese model build succesfully
# Model: "sequential_54"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# 1_C (Conv2D)                 (None, 60, 13, 32)        832
# _________________________________________________________________
# batch_normalization_216 (Bat (None, 60, 13, 32)        128
# _________________________________________________________________
# M_1 (MaxPooling2D)           (None, 30, 6, 32)         0
# _________________________________________________________________
# 2_C (Conv2D)                 (None, 30, 6, 40)         32040
# _________________________________________________________________
# batch_normalization_217 (Bat (None, 30, 6, 40)         160
# _________________________________________________________________
# M_2 (MaxPooling2D)           (None, 15, 3, 40)         0
# _________________________________________________________________
# 3_C (Conv2D)                 (None, 15, 3, 40)         1640
# _________________________________________________________________
# batch_normalization_218 (Bat (None, 15, 3, 40)         160
# _________________________________________________________________
# 4_C (Conv2D)                 (None, 15, 3, 12)         4332
# _________________________________________________________________
# batch_normalization_219 (Bat (None, 15, 3, 12)         48
# _________________________________________________________________
# flatten_54 (Flatten)         (None, 540)               0
# _________________________________________________________________
# dense_162 (Dense)            (None, 432)               233712
# _________________________________________________________________
# dense_163 (Dense)            (None, 60)                25980
# =================================================================
# Total params: 299,032
# Trainable params: 298,784
# Non-trainable params: 248
# _________________________________________________________________
# Model: "functional_109"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_109 (InputLayer)          [(None, 60, 13, 1)]  0
# __________________________________________________________________________________________________
# input_110 (InputLayer)          [(None, 60, 13, 1)]  0
# __________________________________________________________________________________________________
# sequential_54 (Sequential)      (None, 60)           299032      input_109[0][0]
#                                                                  input_110[0][0]
# __________________________________________________________________________________________________
# subtract_54 (Subtract)          (None, 60)           0           sequential_54[0][0]
#                                                                  sequential_54[1][0]
# __________________________________________________________________________________________________
# lambda_54 (Lambda)              (None, 1)            0           subtract_54[0][0]
# __________________________________________________________________________________________________
# dense_164 (Dense)               (None, 1)            2           lambda_54[0][0]
# ==================================================================================================
# Total params: 299,034
# Trainable params: 298,786
# Non-trainable params: 248
# __________________________________________________________________________________________________
# Epoch 1/50
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0117s vs `on_train_batch_end` time: 0.0908s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0063s vs `on_test_batch_end` time: 0.0220s). Check your callbacks.
# 32/32 - 3s - loss: 0.4556 - accuracy: 0.6344 - val_loss: 0.7239 - val_accuracy: 0.1620
# Epoch 2/50
# 32/32 - 3s - loss: 0.3038 - accuracy: 0.8014 - val_loss: 0.6783 - val_accuracy: 0.9572
# Epoch 3/50
# 32/32 - 3s - loss: 0.2787 - accuracy: 0.9842 - val_loss: 0.6616 - val_accuracy: 0.9605
# Epoch 4/50
# 32/32 - 3s - loss: 0.2631 - accuracy: 0.9886 - val_loss: 0.6512 - val_accuracy: 0.9565
# Epoch 5/50
# 32/32 - 3s - loss: 0.2565 - accuracy: 0.9903 - val_loss: 0.6391 - val_accuracy: 0.9597
# Epoch 6/50
# 32/32 - 3s - loss: 0.2478 - accuracy: 0.9913 - val_loss: 0.6284 - val_accuracy: 0.9793
# Epoch 7/50
# 32/32 - 3s - loss: 0.2436 - accuracy: 0.9921 - val_loss: 0.6338 - val_accuracy: 0.9567
# Epoch 8/50
# 32/32 - 3s - loss: 0.2364 - accuracy: 0.9923 - val_loss: 0.6789 - val_accuracy: 0.9383
# Epoch 9/50
# 32/32 - 3s - loss: 0.2307 - accuracy: 0.9916 - val_loss: 0.6132 - val_accuracy: 0.9590
# Epoch 10/50
# 32/32 - 3s - loss: 0.2237 - accuracy: 0.9933 - val_loss: 0.6715 - val_accuracy: 0.8972
# Epoch 11/50
# 32/32 - 3s - loss: 0.2178 - accuracy: 0.9941 - val_loss: 0.5846 - val_accuracy: 0.9840
# Epoch 12/50
# 32/32 - 3s - loss: 0.2127 - accuracy: 0.9933 - val_loss: 0.5803 - val_accuracy: 0.9812
# Epoch 13/50
# 32/32 - 3s - loss: 0.2065 - accuracy: 0.9949 - val_loss: 0.7136 - val_accuracy: 0.8675
# Epoch 14/50
# 32/32 - 3s - loss: 0.2037 - accuracy: 0.9945 - val_loss: 0.5855 - val_accuracy: 0.9570
# Epoch 15/50
# 32/32 - 3s - loss: 0.1984 - accuracy: 0.9951 - val_loss: 0.6665 - val_accuracy: 0.8980
# Epoch 16/50
# 32/32 - 3s - loss: 0.1933 - accuracy: 0.9946 - val_loss: 0.6111 - val_accuracy: 0.9500
# Epoch 17/50
# 32/32 - 3s - loss: 0.1899 - accuracy: 0.9945 - val_loss: 0.5935 - val_accuracy: 0.9168
# Epoch 18/50
# 32/32 - 3s - loss: 0.1848 - accuracy: 0.9949 - val_loss: 0.6967 - val_accuracy: 0.8512
# Epoch 19/50
# 32/32 - 3s - loss: 0.1821 - accuracy: 0.9948 - val_loss: 0.5831 - val_accuracy: 0.9455
# Epoch 20/50
# 32/32 - 3s - loss: 0.1781 - accuracy: 0.9948 - val_loss: 0.5804 - val_accuracy: 0.9268
# Epoch 21/50
# 32/32 - 3s - loss: 0.1730 - accuracy: 0.9953 - val_loss: 0.5021 - val_accuracy: 0.9578
# Epoch 22/50
# 32/32 - 3s - loss: 0.1700 - accuracy: 0.9952 - val_loss: 0.5642 - val_accuracy: 0.9230
# Epoch 23/50
# 32/32 - 3s - loss: 0.1656 - accuracy: 0.9955 - val_loss: 0.5057 - val_accuracy: 0.9585
# Epoch 24/50
# 32/32 - 3s - loss: 0.1622 - accuracy: 0.9955 - val_loss: 0.5505 - val_accuracy: 0.9337
# Epoch 25/50
# 32/32 - 3s - loss: 0.1588 - accuracy: 0.9951 - val_loss: 0.5401 - val_accuracy: 0.9528
# Epoch 26/50
# 32/32 - 3s - loss: 0.1566 - accuracy: 0.9952 - val_loss: 0.5022 - val_accuracy: 0.9550
# Epoch 27/50
# 32/32 - 3s - loss: 0.1542 - accuracy: 0.9951 - val_loss: 0.7942 - val_accuracy: 0.8135
# Epoch 28/50
# 32/32 - 3s - loss: 0.1493 - accuracy: 0.9955 - val_loss: 0.4791 - val_accuracy: 0.9722
# Epoch 29/50
# 32/32 - 3s - loss: 0.1469 - accuracy: 0.9954 - val_loss: 0.4979 - val_accuracy: 0.9555
# Epoch 30/50
# 32/32 - 3s - loss: 0.1447 - accuracy: 0.9949 - val_loss: 0.5284 - val_accuracy: 0.9383
# Epoch 31/50
# 32/32 - 3s - loss: 0.1414 - accuracy: 0.9952 - val_loss: 0.4364 - val_accuracy: 0.9697
# Epoch 32/50
# 32/32 - 3s - loss: 0.1407 - accuracy: 0.9947 - val_loss: 0.6113 - val_accuracy: 0.8808
# Epoch 33/50
# 32/32 - 3s - loss: 0.1356 - accuracy: 0.9956 - val_loss: 0.4327 - val_accuracy: 0.9805
# Epoch 34/50
# 32/32 - 3s - loss: 0.1324 - accuracy: 0.9958 - val_loss: 0.4164 - val_accuracy: 0.9605
# Epoch 35/50
# 32/32 - 3s - loss: 0.1295 - accuracy: 0.9958 - val_loss: 0.4077 - val_accuracy: 0.9830
# Epoch 36/50
# 32/32 - 3s - loss: 0.1272 - accuracy: 0.9960 - val_loss: 0.4599 - val_accuracy: 0.9482
# Epoch 37/50
# 32/32 - 3s - loss: 0.1238 - accuracy: 0.9963 - val_loss: 0.4265 - val_accuracy: 0.9768
# Epoch 38/50
# 32/32 - 3s - loss: 0.1217 - accuracy: 0.9960 - val_loss: 0.3834 - val_accuracy: 0.9833
# Epoch 39/50
# 32/32 - 3s - loss: 0.1191 - accuracy: 0.9961 - val_loss: 0.3938 - val_accuracy: 0.9588
# Epoch 40/50
# 32/32 - 3s - loss: 0.1172 - accuracy: 0.9961 - val_loss: 0.3889 - val_accuracy: 0.9592
# Epoch 41/50
# 32/32 - 3s - loss: 0.1148 - accuracy: 0.9960 - val_loss: 0.3672 - val_accuracy: 0.9833
# Epoch 42/50
# 32/32 - 3s - loss: 0.1129 - accuracy: 0.9959 - val_loss: 0.4065 - val_accuracy: 0.9423
# Epoch 43/50
# 32/32 - 3s - loss: 0.1110 - accuracy: 0.9960 - val_loss: 0.3856 - val_accuracy: 0.9590
# Epoch 44/50
# 32/32 - 3s - loss: 0.1086 - accuracy: 0.9961 - val_loss: 0.3874 - val_accuracy: 0.9590
# Epoch 45/50
# 32/32 - 3s - loss: 0.1064 - accuracy: 0.9959 - val_loss: 0.3906 - val_accuracy: 0.9575
# Epoch 46/50
# 32/32 - 3s - loss: 0.1040 - accuracy: 0.9961 - val_loss: 0.3801 - val_accuracy: 0.9590
# Epoch 47/50
# 32/32 - 3s - loss: 0.1027 - accuracy: 0.9961 - val_loss: 0.4015 - val_accuracy: 0.9550
# Epoch 48/50
# 32/32 - 3s - loss: 0.1001 - accuracy: 0.9956 - val_loss: 0.3425 - val_accuracy: 0.9833
# Epoch 49/50
# 32/32 - 3s - loss: 0.0983 - accuracy: 0.9959 - val_loss: 0.3703 - val_accuracy: 0.9538
# Epoch 50/50
# 32/32 - 3s - loss: 0.0963 - accuracy: 0.9961 - val_loss: 0.3431 - val_accuracy: 0.9825

# %%
siamese_model_dependent_equal = train_siamese_equal(train_set_dependent, verbose=False)
# Out:
# (1500, 60, 13)
# (1500, 60, 13)
# Base Model initialized successfully
# Siamese model build succesfully
# Epoch 1/50
# 33/33 - 1s - loss: 0.6743 - accuracy: 0.3900 - val_loss: 0.5969 - val_accuracy: 0.9800
# Epoch 2/50
# 33/33 - 0s - loss: 0.5353 - accuracy: 0.5025 - val_loss: 0.5405 - val_accuracy: 0.9500
# Epoch 3/50
# 33/33 - 0s - loss: 0.4923 - accuracy: 0.6908 - val_loss: 0.3269 - val_accuracy: 0.9300
# Epoch 4/50
# 33/33 - 0s - loss: 0.4614 - accuracy: 0.9450 - val_loss: 0.1957 - val_accuracy: 0.9367
# Epoch 5/50
# 33/33 - 0s - loss: 0.4400 - accuracy: 0.9533 - val_loss: 0.1378 - val_accuracy: 0.9400
# Epoch 6/50
# 33/33 - 0s - loss: 0.4264 - accuracy: 0.9542 - val_loss: 0.1135 - val_accuracy: 0.9367
# Epoch 7/50
# 33/33 - 0s - loss: 0.4138 - accuracy: 0.9550 - val_loss: 0.0759 - val_accuracy: 0.9367
# Epoch 8/50
# 33/33 - 0s - loss: 0.4008 - accuracy: 0.9642 - val_loss: 0.0702 - val_accuracy: 0.9367
# Epoch 9/50
# 33/33 - 0s - loss: 0.3973 - accuracy: 0.9600 - val_loss: 0.0695 - val_accuracy: 0.9367
# Epoch 10/50
# 33/33 - 0s - loss: 0.3915 - accuracy: 0.9558 - val_loss: 0.0661 - val_accuracy: 0.9400
# Epoch 11/50
# 33/33 - 0s - loss: 0.3715 - accuracy: 0.9650 - val_loss: 0.0582 - val_accuracy: 0.9400
# Epoch 12/50
# 33/33 - 0s - loss: 0.3621 - accuracy: 0.9667 - val_loss: 0.0575 - val_accuracy: 0.9433
# Epoch 13/50
# 33/33 - 0s - loss: 0.3541 - accuracy: 0.9700 - val_loss: 0.0584 - val_accuracy: 0.9400
# Epoch 14/50
# 33/33 - 0s - loss: 0.3472 - accuracy: 0.9683 - val_loss: 0.0591 - val_accuracy: 0.9400
# Epoch 15/50
# 33/33 - 0s - loss: 0.3385 - accuracy: 0.9700 - val_loss: 0.0590 - val_accuracy: 0.9367
# Epoch 16/50
# 33/33 - 0s - loss: 0.3312 - accuracy: 0.9717 - val_loss: 0.0607 - val_accuracy: 0.9400
# Epoch 17/50
# 33/33 - 0s - loss: 0.3292 - accuracy: 0.9683 - val_loss: 0.0671 - val_accuracy: 0.9367
# Epoch 18/50
# 33/33 - 0s - loss: 0.3210 - accuracy: 0.9700 - val_loss: 0.0695 - val_accuracy: 0.9367
# Epoch 19/50
# 33/33 - 0s - loss: 0.3145 - accuracy: 0.9725 - val_loss: 0.0644 - val_accuracy: 0.9400
# Epoch 20/50
# 33/33 - 0s - loss: 0.3048 - accuracy: 0.9767 - val_loss: 0.0619 - val_accuracy: 0.9467
# Epoch 21/50
# 33/33 - 0s - loss: 0.2997 - accuracy: 0.9750 - val_loss: 0.0648 - val_accuracy: 0.9400
# Epoch 22/50
# 33/33 - 0s - loss: 0.2922 - accuracy: 0.9792 - val_loss: 0.0622 - val_accuracy: 0.9467
# Epoch 23/50
# 33/33 - 0s - loss: 0.2864 - accuracy: 0.9792 - val_loss: 0.0772 - val_accuracy: 0.9433
# Epoch 24/50
# 33/33 - 0s - loss: 0.2836 - accuracy: 0.9767 - val_loss: 0.0768 - val_accuracy: 0.9467
# Epoch 25/50
# 33/33 - 0s - loss: 0.2819 - accuracy: 0.9717 - val_loss: 0.0744 - val_accuracy: 0.9367
# Epoch 26/50
# 33/33 - 0s - loss: 0.2731 - accuracy: 0.9775 - val_loss: 0.0667 - val_accuracy: 0.9500
# Epoch 27/50
# 33/33 - 0s - loss: 0.2653 - accuracy: 0.9817 - val_loss: 0.0651 - val_accuracy: 0.9500
# Epoch 28/50
# 33/33 - 0s - loss: 0.2620 - accuracy: 0.9783 - val_loss: 0.0670 - val_accuracy: 0.9500
# Epoch 29/50
# 33/33 - 0s - loss: 0.2559 - accuracy: 0.9808 - val_loss: 0.0667 - val_accuracy: 0.9500
# Epoch 30/50
# 33/33 - 0s - loss: 0.2521 - accuracy: 0.9792 - val_loss: 0.0709 - val_accuracy: 0.9467
# Epoch 31/50
# 33/33 - 0s - loss: 0.2464 - accuracy: 0.9817 - val_loss: 0.0700 - val_accuracy: 0.9500
# Epoch 32/50
# 33/33 - 0s - loss: 0.2418 - accuracy: 0.9825 - val_loss: 0.0689 - val_accuracy: 0.9500
# Epoch 33/50
# 33/33 - 0s - loss: 0.2380 - accuracy: 0.9825 - val_loss: 0.0705 - val_accuracy: 0.9500
# Epoch 34/50
# 33/33 - 0s - loss: 0.2340 - accuracy: 0.9817 - val_loss: 0.0723 - val_accuracy: 0.9500
# Epoch 35/50
# 33/33 - 0s - loss: 0.2306 - accuracy: 0.9817 - val_loss: 0.0720 - val_accuracy: 0.9500
# Epoch 36/50
# 33/33 - 0s - loss: 0.2270 - accuracy: 0.9808 - val_loss: 0.0727 - val_accuracy: 0.9500
# Epoch 37/50
# 33/33 - 0s - loss: 0.2214 - accuracy: 0.9825 - val_loss: 0.0735 - val_accuracy: 0.9500
# Epoch 38/50
# 33/33 - 0s - loss: 0.2179 - accuracy: 0.9825 - val_loss: 0.0744 - val_accuracy: 0.9500
# Epoch 39/50
# 33/33 - 0s - loss: 0.2156 - accuracy: 0.9825 - val_loss: 0.0760 - val_accuracy: 0.9500
# Epoch 40/50
# 33/33 - 0s - loss: 0.2115 - accuracy: 0.9825 - val_loss: 0.0752 - val_accuracy: 0.9500
# Epoch 41/50
# 33/33 - 0s - loss: 0.2081 - accuracy: 0.9825 - val_loss: 0.0759 - val_accuracy: 0.9500
# Epoch 42/50
# 33/33 - 0s - loss: 0.2042 - accuracy: 0.9825 - val_loss: 0.0770 - val_accuracy: 0.9500
# Epoch 43/50
# 33/33 - 0s - loss: 0.2011 - accuracy: 0.9825 - val_loss: 0.0775 - val_accuracy: 0.9500
# Epoch 44/50
# 33/33 - 0s - loss: 0.1977 - accuracy: 0.9825 - val_loss: 0.0779 - val_accuracy: 0.9500
# Epoch 45/50
# 33/33 - 0s - loss: 0.1954 - accuracy: 0.9825 - val_loss: 0.0803 - val_accuracy: 0.9500
# Epoch 46/50
# 33/33 - 0s - loss: 0.1922 - accuracy: 0.9825 - val_loss: 0.0795 - val_accuracy: 0.9500
# Epoch 47/50
# 33/33 - 0s - loss: 0.1887 - accuracy: 0.9825 - val_loss: 0.0806 - val_accuracy: 0.9500
# Epoch 48/50
# 33/33 - 0s - loss: 0.1863 - accuracy: 0.9825 - val_loss: 0.0810 - val_accuracy: 0.9500
# Epoch 49/50
# 33/33 - 0s - loss: 0.1834 - accuracy: 0.9825 - val_loss: 0.0819 - val_accuracy: 0.9500
# Epoch 50/50
# 33/33 - 0s - loss: 0.1804 - accuracy: 0.9825 - val_loss: 0.0827 - val_accuracy: 0.9500

# %%
siamese_model_limited_equal = train_siamese_equal(train_set_limited, verbose=False)
# Out:
# (15000, 60, 13)
# (15000, 60, 13)
# Base Model initialized successfully
# Siamese model build succesfully
# Epoch 1/50
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0123s vs `on_train_batch_end` time: 0.0695s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0044s vs `on_test_batch_end` time: 0.0176s). Check your callbacks.
# 32/32 - 3s - loss: 0.6312 - accuracy: 0.6653 - val_loss: 0.6735 - val_accuracy: 0.5490
# Epoch 2/50
# 32/32 - 2s - loss: 0.4837 - accuracy: 0.9295 - val_loss: 0.6060 - val_accuracy: 0.7327
# Epoch 3/50
# 32/32 - 2s - loss: 0.4375 - accuracy: 0.9656 - val_loss: 0.5528 - val_accuracy: 0.7250
# Epoch 4/50
# 32/32 - 2s - loss: 0.4245 - accuracy: 0.9719 - val_loss: 0.4653 - val_accuracy: 0.8310
# Epoch 5/50
# 32/32 - 2s - loss: 0.4067 - accuracy: 0.9747 - val_loss: 0.2308 - val_accuracy: 0.9440
# Epoch 6/50
# 32/32 - 2s - loss: 0.3973 - accuracy: 0.9749 - val_loss: 0.2835 - val_accuracy: 0.9097
# Epoch 7/50
# 32/32 - 2s - loss: 0.3846 - accuracy: 0.9783 - val_loss: 0.1643 - val_accuracy: 0.9390
# Epoch 8/50
# 32/32 - 2s - loss: 0.3774 - accuracy: 0.9789 - val_loss: 0.2153 - val_accuracy: 0.9343
# Epoch 9/50
# 32/32 - 2s - loss: 0.3684 - accuracy: 0.9797 - val_loss: 0.1508 - val_accuracy: 0.9517
# Epoch 10/50
# 32/32 - 2s - loss: 0.3583 - accuracy: 0.9828 - val_loss: 0.1522 - val_accuracy: 0.9510
# Epoch 11/50
# 32/32 - 2s - loss: 0.3504 - accuracy: 0.9823 - val_loss: 0.1407 - val_accuracy: 0.9400
# Epoch 12/50
# 32/32 - 2s - loss: 0.3433 - accuracy: 0.9808 - val_loss: 0.1593 - val_accuracy: 0.9413
# Epoch 13/50
# 32/32 - 2s - loss: 0.3346 - accuracy: 0.9852 - val_loss: 0.1750 - val_accuracy: 0.9237
# Epoch 14/50
# 32/32 - 2s - loss: 0.3260 - accuracy: 0.9880 - val_loss: 0.1608 - val_accuracy: 0.9353
# Epoch 15/50
# 32/32 - 2s - loss: 0.3183 - accuracy: 0.9893 - val_loss: 0.1563 - val_accuracy: 0.9323
# Epoch 16/50
# 32/32 - 2s - loss: 0.3119 - accuracy: 0.9881 - val_loss: 0.1281 - val_accuracy: 0.9433
# Epoch 17/50
# 32/32 - 2s - loss: 0.3043 - accuracy: 0.9909 - val_loss: 0.1127 - val_accuracy: 0.9477
# Epoch 18/50
# 32/32 - 2s - loss: 0.2979 - accuracy: 0.9915 - val_loss: 0.1245 - val_accuracy: 0.9400
# Epoch 19/50
# 32/32 - 2s - loss: 0.2922 - accuracy: 0.9909 - val_loss: 0.1566 - val_accuracy: 0.9303
# Epoch 20/50
# 32/32 - 2s - loss: 0.2855 - accuracy: 0.9914 - val_loss: 0.1069 - val_accuracy: 0.9517
# Epoch 21/50
# 32/32 - 2s - loss: 0.2796 - accuracy: 0.9917 - val_loss: 0.1113 - val_accuracy: 0.9513
# Epoch 22/50
# 32/32 - 2s - loss: 0.2731 - accuracy: 0.9924 - val_loss: 0.1222 - val_accuracy: 0.9400
# Epoch 23/50
# 32/32 - 2s - loss: 0.2676 - accuracy: 0.9924 - val_loss: 0.1354 - val_accuracy: 0.9413
# Epoch 24/50
# 32/32 - 2s - loss: 0.2621 - accuracy: 0.9924 - val_loss: 0.1487 - val_accuracy: 0.9253
# Epoch 25/50
# 32/32 - 2s - loss: 0.2568 - accuracy: 0.9924 - val_loss: 0.1191 - val_accuracy: 0.9470
# Epoch 26/50
# 32/32 - 2s - loss: 0.2518 - accuracy: 0.9924 - val_loss: 0.1382 - val_accuracy: 0.9310
# Epoch 27/50
# 32/32 - 2s - loss: 0.2465 - accuracy: 0.9923 - val_loss: 0.1377 - val_accuracy: 0.9300
# Epoch 28/50
# 32/32 - 2s - loss: 0.2420 - accuracy: 0.9924 - val_loss: 0.1411 - val_accuracy: 0.9273
# Epoch 29/50
# 32/32 - 2s - loss: 0.2369 - accuracy: 0.9923 - val_loss: 0.2365 - val_accuracy: 0.8837
# Epoch 30/50
# 32/32 - 2s - loss: 0.2323 - accuracy: 0.9924 - val_loss: 0.2167 - val_accuracy: 0.8800
# Epoch 31/50
# 32/32 - 2s - loss: 0.2279 - accuracy: 0.9924 - val_loss: 0.1769 - val_accuracy: 0.9183
# Epoch 32/50
# 32/32 - 2s - loss: 0.2234 - accuracy: 0.9924 - val_loss: 0.1679 - val_accuracy: 0.9110
# Epoch 33/50
# 32/32 - 2s - loss: 0.2195 - accuracy: 0.9924 - val_loss: 0.1550 - val_accuracy: 0.9253
# Epoch 34/50
# 32/32 - 2s - loss: 0.2149 - accuracy: 0.9924 - val_loss: 0.1424 - val_accuracy: 0.9353
# Epoch 35/50
# 32/32 - 2s - loss: 0.2107 - accuracy: 0.9924 - val_loss: 0.1486 - val_accuracy: 0.9307
# Epoch 36/50
# 32/32 - 2s - loss: 0.2068 - accuracy: 0.9924 - val_loss: 0.1195 - val_accuracy: 0.9457
# Epoch 37/50
# 32/32 - 2s - loss: 0.2030 - accuracy: 0.9924 - val_loss: 0.1683 - val_accuracy: 0.9053
# Epoch 38/50
# 32/32 - 2s - loss: 0.2275 - accuracy: 0.9775 - val_loss: 0.7041 - val_accuracy: 0.5347
# Epoch 39/50
# 32/32 - 2s - loss: 0.2144 - accuracy: 0.9834 - val_loss: 0.6272 - val_accuracy: 0.5903
# Epoch 40/50
# 32/32 - 2s - loss: 0.1961 - accuracy: 0.9905 - val_loss: 0.2908 - val_accuracy: 0.8233
# Epoch 41/50
# 32/32 - 2s - loss: 0.1900 - accuracy: 0.9920 - val_loss: 0.1656 - val_accuracy: 0.9073
# Epoch 42/50
# 32/32 - 2s - loss: 0.1859 - accuracy: 0.9924 - val_loss: 0.1643 - val_accuracy: 0.9043
# Epoch 43/50
# 32/32 - 2s - loss: 0.1827 - accuracy: 0.9923 - val_loss: 0.1722 - val_accuracy: 0.9010
# Epoch 44/50
# 32/32 - 2s - loss: 0.1789 - accuracy: 0.9925 - val_loss: 0.1338 - val_accuracy: 0.9383
# Epoch 45/50
# 32/32 - 2s - loss: 0.1755 - accuracy: 0.9925 - val_loss: 0.1234 - val_accuracy: 0.9377
# Epoch 46/50
# 32/32 - 2s - loss: 0.1723 - accuracy: 0.9925 - val_loss: 0.1217 - val_accuracy: 0.9377
# Epoch 47/50
# 32/32 - 2s - loss: 0.1696 - accuracy: 0.9925 - val_loss: 0.1247 - val_accuracy: 0.9393
# Epoch 48/50
# 32/32 - 2s - loss: 0.1666 - accuracy: 0.9925 - val_loss: 0.1224 - val_accuracy: 0.9397
# Epoch 49/50
# 32/32 - 2s - loss: 0.1642 - accuracy: 0.9925 - val_loss: 0.1348 - val_accuracy: 0.9347
# Epoch 50/50
# 32/32 - 2s - loss: 0.1613 - accuracy: 0.9925 - val_loss: 0.1185 - val_accuracy: 0.9423

# %%
siamese_model_independent_equal = train_siamese_equal(train_set_independent, verbose=False)
# Out:
# (15000, 60, 13)
# (15000, 60, 13)
# Base Model initialized successfully
# Siamese model build succesfully
# Epoch 1/50
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0260s vs `on_train_batch_end` time: 0.0525s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0072s vs `on_test_batch_end` time: 0.0159s). Check your callbacks.
# 32/32 - 3s - loss: 0.6012 - accuracy: 0.6734 - val_loss: 0.7090 - val_accuracy: 0.0197
# Epoch 2/50
# 32/32 - 2s - loss: 0.4550 - accuracy: 0.9616 - val_loss: 0.7268 - val_accuracy: 0.0197
# Epoch 3/50
# 32/32 - 2s - loss: 0.4344 - accuracy: 0.9701 - val_loss: 0.7271 - val_accuracy: 0.1257
# Epoch 4/50
# 32/32 - 2s - loss: 0.4189 - accuracy: 0.9738 - val_loss: 0.6324 - val_accuracy: 0.5233
# Epoch 5/50
# 32/32 - 2s - loss: 0.4047 - accuracy: 0.9753 - val_loss: 0.6297 - val_accuracy: 0.4773
# Epoch 6/50
# 32/32 - 2s - loss: 0.3959 - accuracy: 0.9773 - val_loss: 0.0870 - val_accuracy: 0.9650
# Epoch 7/50
# 32/32 - 2s - loss: 0.3871 - accuracy: 0.9782 - val_loss: 0.0864 - val_accuracy: 0.9657
# Epoch 8/50
# 32/32 - 2s - loss: 0.3776 - accuracy: 0.9798 - val_loss: 0.0436 - val_accuracy: 0.9647
# Epoch 9/50
# 32/32 - 2s - loss: 0.3693 - accuracy: 0.9799 - val_loss: 0.0481 - val_accuracy: 0.9637
# Epoch 10/50
# 32/32 - 2s - loss: 0.3592 - accuracy: 0.9836 - val_loss: 0.0466 - val_accuracy: 0.9633
# Epoch 11/50
# 32/32 - 2s - loss: 0.3507 - accuracy: 0.9850 - val_loss: 0.0456 - val_accuracy: 0.9633
# Epoch 12/50
# 32/32 - 2s - loss: 0.3433 - accuracy: 0.9849 - val_loss: 0.0560 - val_accuracy: 0.9637
# Epoch 13/50
# 32/32 - 2s - loss: 0.3353 - accuracy: 0.9866 - val_loss: 0.0878 - val_accuracy: 0.9637
# Epoch 14/50
# 32/32 - 2s - loss: 0.3281 - accuracy: 0.9858 - val_loss: 0.1033 - val_accuracy: 0.9637
# Epoch 15/50
# 32/32 - 2s - loss: 0.3220 - accuracy: 0.9845 - val_loss: 0.0583 - val_accuracy: 0.9637
# Epoch 16/50
# 32/32 - 2s - loss: 0.3146 - accuracy: 0.9856 - val_loss: 0.0760 - val_accuracy: 0.9640
# Epoch 17/50
# 32/32 - 2s - loss: 0.3081 - accuracy: 0.9868 - val_loss: 0.0703 - val_accuracy: 0.9637
# Epoch 18/50
# 32/32 - 2s - loss: 0.3012 - accuracy: 0.9877 - val_loss: 0.0873 - val_accuracy: 0.9640
# Epoch 19/50
# 32/32 - 2s - loss: 0.2932 - accuracy: 0.9915 - val_loss: 0.1380 - val_accuracy: 0.9640
# Epoch 20/50
# 32/32 - 2s - loss: 0.2870 - accuracy: 0.9913 - val_loss: 0.0766 - val_accuracy: 0.9640
# Epoch 21/50
# 32/32 - 2s - loss: 0.2816 - accuracy: 0.9911 - val_loss: 0.1551 - val_accuracy: 0.9630
# Epoch 22/50
# 32/32 - 2s - loss: 0.2953 - accuracy: 0.9798 - val_loss: 0.0375 - val_accuracy: 0.9727
# Epoch 23/50
# 32/32 - 2s - loss: 0.2733 - accuracy: 0.9879 - val_loss: 0.0343 - val_accuracy: 0.9717
# Epoch 24/50
# 32/32 - 2s - loss: 0.2667 - accuracy: 0.9898 - val_loss: 0.0370 - val_accuracy: 0.9677
# Epoch 25/50
# 32/32 - 2s - loss: 0.2601 - accuracy: 0.9913 - val_loss: 0.0376 - val_accuracy: 0.9657
# Epoch 26/50
# 32/32 - 2s - loss: 0.2547 - accuracy: 0.9916 - val_loss: 0.0367 - val_accuracy: 0.9687
# Epoch 27/50
# 32/32 - 2s - loss: 0.2496 - accuracy: 0.9916 - val_loss: 0.0398 - val_accuracy: 0.9647
# Epoch 28/50
# 32/32 - 2s - loss: 0.2449 - accuracy: 0.9916 - val_loss: 0.0372 - val_accuracy: 0.9660
# Epoch 29/50
# 32/32 - 2s - loss: 0.2399 - accuracy: 0.9916 - val_loss: 0.0387 - val_accuracy: 0.9663
# Epoch 30/50
# 32/32 - 2s - loss: 0.2354 - accuracy: 0.9916 - val_loss: 0.0406 - val_accuracy: 0.9647
# Epoch 31/50
# 32/32 - 2s - loss: 0.2307 - accuracy: 0.9916 - val_loss: 0.0457 - val_accuracy: 0.9637
# Epoch 32/50
# 32/32 - 2s - loss: 0.2262 - accuracy: 0.9918 - val_loss: 0.0429 - val_accuracy: 0.9637
# Epoch 33/50
# 32/32 - 2s - loss: 0.2219 - accuracy: 0.9917 - val_loss: 0.0429 - val_accuracy: 0.9650
# Epoch 34/50
# 32/32 - 2s - loss: 0.2181 - accuracy: 0.9916 - val_loss: 0.0395 - val_accuracy: 0.9660
# Epoch 35/50
# 32/32 - 2s - loss: 0.2139 - accuracy: 0.9918 - val_loss: 0.0397 - val_accuracy: 0.9660
# Epoch 36/50
# 32/32 - 2s - loss: 0.2100 - accuracy: 0.9918 - val_loss: 0.0436 - val_accuracy: 0.9640
# Epoch 37/50
# 32/32 - 2s - loss: 0.2057 - accuracy: 0.9918 - val_loss: 0.0422 - val_accuracy: 0.9640
# Epoch 38/50
# 32/32 - 2s - loss: 0.2017 - accuracy: 0.9918 - val_loss: 0.0458 - val_accuracy: 0.9637
# Epoch 39/50
# 32/32 - 2s - loss: 0.1980 - accuracy: 0.9918 - val_loss: 0.0456 - val_accuracy: 0.9637
# Epoch 40/50
# 32/32 - 2s - loss: 0.1944 - accuracy: 0.9918 - val_loss: 0.0464 - val_accuracy: 0.9637
# Epoch 41/50
# 32/32 - 2s - loss: 0.1910 - accuracy: 0.9918 - val_loss: 0.0434 - val_accuracy: 0.9647
# Epoch 42/50
# 32/32 - 2s - loss: 0.1877 - accuracy: 0.9918 - val_loss: 0.0486 - val_accuracy: 0.9637
# Epoch 43/50
# 32/32 - 2s - loss: 0.1843 - accuracy: 0.9918 - val_loss: 0.0550 - val_accuracy: 0.9637
# Epoch 44/50
# 32/32 - 2s - loss: 0.1814 - accuracy: 0.9918 - val_loss: 0.0493 - val_accuracy: 0.9637
# Epoch 45/50
# 32/32 - 2s - loss: 0.1781 - accuracy: 0.9918 - val_loss: 0.0667 - val_accuracy: 0.9637
# Epoch 46/50
# 32/32 - 2s - loss: 0.1744 - accuracy: 0.9918 - val_loss: 0.1058 - val_accuracy: 0.9637
# Epoch 47/50
# 32/32 - 2s - loss: 0.1716 - accuracy: 0.9918 - val_loss: 0.1871 - val_accuracy: 0.9630
# Epoch 48/50
# 32/32 - 2s - loss: 0.1687 - accuracy: 0.9919 - val_loss: 0.0665 - val_accuracy: 0.9637
# Epoch 49/50
# 32/32 - 2s - loss: 0.1654 - accuracy: 0.9919 - val_loss: 0.1121 - val_accuracy: 0.9637
# Epoch 50/50
# 32/32 - 2s - loss: 0.1624 - accuracy: 0.9919 - val_loss: 0.1808 - val_accuracy: 0.9630

# %%
save_temp = False
save_drive = True

if save_temp == True:
   # Save trained models.
    siamese_model_basic_equal.save("basic_model_equal.h5")
    siamese_model_dependent_equal.save("dependent_model_equal.h5")
    siamese_model_limited_equal.save("limited_model_equal.h5")
    siamese_model_independent_equal.save("independent_model_equal.h5")

if save_drive == True:
  # Save trained models to Drive.
  path = "/content/drive/MyDrive/basic_model_equal.h5"
  siamese_model_basic_equal.save(path)

  path = "/content/drive/MyDrive/dependent_model_equal.h5"
  siamese_model_dependent_equal.save(path)

  path = "/content/drive/MyDrive/limited_model_equal.h5"
  siamese_model_limited_equal.save(path)

  path = "/content/drive/MyDrive/independent_model_equal.h5"
  siamese_model_independent_equal.save(path)

# %%
load_temp = False
load_drive = True

if load_temp == True:
  # Load trained models for re-use from runtime.
  siamese_model_basic_equal = tf.keras.models.load_model("basic_model_equal.h5")
  siamese_model_dependent_equal = tf.keras.models.load_model("dependent_model_equal.h5")
  siamese_model_limited_equal = tf.keras.models.load_model("limited_model_equal.h5")
  siamese_model_independent_equal = tf.keras.models.load_model("independent_model_equal.h5")

if load_drive == True:
  # Load trained models for re-use from Drive.
  path = "/content/drive/MyDrive/basic_model_equal.h5"
  siamese_model_basic_equal = tf.keras.models.load_model(path)

  path = "/content/drive/MyDrive/dependent_model_equal.h5"
  siamese_model_dependent_equal = tf.keras.models.load_model(path)

  path = "/content/drive/MyDrive/limited_model_equal.h5"
  siamese_model_limited_equal = tf.keras.models.load_model(path)

  path = "/content/drive/MyDrive/independent_model_equal.h5"
  siamese_model_independent_equal = tf.keras.models.load_model(path)

# %% [markdown]
# If any issues arise when fitting or predicting, explain why?
#
# >There is some issues with context dependent and limited sets, as their loss-seems to not reduce, which indicates, that the Model is not learning at all. This might be partially, because of the really biased data on the Train Sets as tehy are formed using only same digit or portion that has huge variance.

# %% [markdown]
# # Experiments and results
#
# Describe your experiments setup
#
# * which metrics are used for evaluation?
#
# > Right now the binary-crossentropy is used as loss metric for the model and binary-accuracy is used for the accuracy metric.
#
# > The prediction for speaker verification is based on the similarity scores between given samples and the actual target value.
#
# * what are the baseline methods?
#
# > Not one specific base-line method was found or applied as all the previous works found were done with too different types of setups to actually prove worthy for trying.
#
# > Trying to accomplish in generating my own base-line method also did not succeed very well...
#
# * How do you run the experiments?
#
# > The Models are trained individually on dedicated Train Sets and then predictions are drawn and they are evaluated indivudually on the dedicated Test Sets. The dedicated Sets are used for training Models in speficif scenarios, where the training data and testing data are formed in a way, that certain types of result could be expected.
#
# > The Models are trained for 100 epochs and with relatively large batch size. Lots of different variations on epochs and batch sizes were tested, but they yielded very varying result, which were less promising.
#
# > Later on the Models are used to predict on new unseen data from totally different scenario and evaluated on it, in order to evaluate the transferability of the set.
#
# >Also noteable is, that the Models can be saved, in order to continue training and evaluation later on.
#
# * And finally what is the results and your analysis, also some discussion.
#
# > The result of the anylysis is, that the Models seemed to lear well, but the random selection for the train inputs caused a scenario where the propability of the speakers to actually be the same, was really low, thus affecting the training and evaluation of the Models. This could be easily fixed by adding more scenarios, where the speakeakers were same, but for this project, the randomly selecting training samples was instructed. Instead slight adjustments were done by manipulating weights based on the occurrance rates of same / not same speakers.
#
# > Even tho, that Models learned well, and the loss was reduces for both validation and training data, the accuracy was high mainly due to reasons listed in the section above. So in conclusion, the end result is Models, which are most likely not goign to be able to verify the speaker, but are more likely to verify, that the speaker is not who he claims to be based on audio sample.
#
# > Also, because of the validation split, the validation accuracy could be higher and validation loss lower than actual training accuracy or training loss. This is due to factor, that if the validation data had the true values in it (cases where the speakers were actually same), those scenarios would cause more shifting in the weights than the scenarios, where validation data did not had any occurrancers of same speakers.
#
# > The test setup was nice and lots of conclusion could have been draw, in which way the training and evaluation of the Models shoudl have / and should not have been done. In further research it would be practical to create a scenario, where all of the Models are trained on equal number of samples for each scenario (same speaker / not same speaker) and see how the Models perform then by themselves on the similar test data, that was used in this project, and also how they would then perform with other scenarios test data and compare the results to this project. Hypothesis being, that they would outperform Models presented in this project.

# %% [markdown]
# ## Baseline method description
#
# Description of the baseline method for comparison if you have one (this is a bonus point)

# %% [markdown]
# ## Results and discussion
#
# Describe the metrics you used to evaluate your algorithms (methods)
#
# >Tensorflow Keras Model.predict and Model.Evaluate were used to provide  information about Models performance on data.
#
# >DET-curves were used, but their effectivenes was not really good, due to random sampling related issues, where the truth values from the evaluations, were pretty much homogenic (all scenarios, where speakers were different).
# Sampling option was provided to present some results, which yielded only the fact that usually the models were pretty bad at predicting correct values, if the data was not homogenous (even the Models trained with more equally spread data).
#
# How is the performance of the algorithm?
#
# Good? Why it is good?
#
# >Algorithm seems to be learning to at least predict well on homogenous data, and the loss values were dropping, which indicates, that the Model was actually learning atleast something. This was not too negative tho, as the setup was more towards providing really heterogenous results as the random sapling yields mostly only similar results (not the same speaker), so the Models performance did not came as a surprise.
#
# Bad? Why it is bad?
#
# >Algorithm does not perform well on more heterogenous data, as the Model of the Neural Network provided for the training, was obviously not optimally build for that, as the main setup was to train with randomized data picking, which yielded very biased results.
#
# What could be good improvements for your methods?
#
# > The results are really biased from most of the cases, as the amount of true values (where speakers are the same) is really low and even the weight manipulation can't solve the issue effectively enough. This affects tremendously on the outcome from the training and thus also to prediction and evaluation. (The sample taking was instructed tho to be done with random selection, which lead to this scenario, so it was not fixed for this particular project in other wasy, than providing a little method to make more equally sampled traning and testing, but there was not enough time for me to actually make it efficient to provide more relevant results). The Models trained with less biased data, did not perfrm very well on the evaluation, with any sets, but seemed to predict a lot of false negatives and/or positives.
#
# > it is also notable that the Model for the Neural Network created, was not optimal for the training of the Models with less biased data, as the validation loss indicates in some cases, that the parameters should have been tweaked (at least the learning rate, seemed to be relatively high and was maybe reason behinf the fluctuation of the loss).
#
# > Doing gridsearch to find more optimized parameters for the Model and understanding better the functionalities behind the Models behavior would be beneficial.
#
# > Finding and implementing more accurate evalution metrics would be also helpful.
#
# >Also, as a newcomer to the field, trying methods on different scenario, where the setup would first be more basic, in order to get a hang on the methods better, before diving to the deep end would also be sufficient.

# %% [markdown]
# Here is the specific test module for the basic scenario. For some reason seems to crash the runtime so was not useful (probably due to too large set of data for the non-target scores). The basic set can be tested with the normal Test Module it needed.

# %%
# Test basic scenario siamese Model agains target and non-target scores.
def test_basic_scenario_siamese(siamese_model, test_samples, verbose:bool = False):

    # MFCCs for each sample/speaker in Test Set.
    test_mfccs = test_samples["mfcc"]

    # Generate Target scores, 10 x MFCCs from utterances from same speaker for each speaker.
    target_scores = []
    for i in range(len(test_samples)):
        speaker = test_samples["spk"].iloc[i]
        mfccs_speaker = test_samples.loc[test_samples["spk"] == speaker, "mfcc"]
        mfccs_target = random.sample(list(mfccs_speaker), 10)
        for value in mfccs_target:
          target_scores.append(value)

    # Generate Non-target scores 50 x MFCCs from utterances from different speaker for each speaker.
    non_target_scores = []
    for i in range(len(test_samples)):
        speaker = test_samples["spk"].iloc[i]
        mfccs_not_speaker = test_samples.loc[test_samples["spk"] != speaker, "mfcc"]
        mfccs_non_target = random.sample(list(mfccs_not_speaker), 50)
        for value in mfccs_non_target:
          non_target_scores.append(mfccs_non_target)

    # Take MFCCs for Target scores.
    mfccs_targets = np.array(target_scores)
    print(mfccs_targets.shape)

    # Take MFCCs for Non-target scores.
    mfccs_non_targets = np.array(non_target_scores)
    print(mfccs_non_targets.shape)

    # Generate correct input format for NNW for Target scores.
    mfccs_input_targets = np.zeros((mfccs_targets.shape[0], 60, 13))
    for i in range(len(mfccs_targets)):
        mfccs_input_targets[i, :] = mfccs_targets[i]

    # Generate correct input format for NNW for Non-target scores.
    mfccs_input_non_targets = np.zeros((mfccs_nontargets.shape[0], 60, 13))
    for i in range(len(mfccs_nontargets)):
        mfccs_input_non_targets[i, :] = mfccs_nontargets[i]

    # Sanity checks.
    print(mfccs_input_targets.shape)
    print(mfccs_input_non_targets.shape)

    # Reshape.
    mfccs_input_targets = mfccs_input_targets.reshape((-1, 60, 13, 1))
    mfccs_input_non_targets = mfccs_input_non_targets.reshape((-1, 60, 13, 1))

    # Evaluate on loop.
    counter_target = 0
    counter_non_target = 0

    # Y true values.
    y_true_target = np.ones(len(test_mfccs))
    y_true_non_target = np.zeros(len(test_mfccs))

    # Iterate over all MFCC samples in 
    for i in range(len(test_mfccs)):
        
        # Predict with model.
        prediction = siamese_model.predict([test_mfccs[i], mfccs_input_targets[counter_target:counter_target+10]])
        print(prediction)     

        # Evaluation score with Target-scores.
        eval_score = siamese_model.evaluate([test_mfccs[i], mfccs_input_targets[counter_target:counter_target+10]], 
                                            y=[mfccs_input_targets[counter_target:counter_target+10]], verbose=2)
        print(eval_score)

        counter_target += 10

        # Predict with model.
        prediction = siamese_model.predict([test_mfccs[i], mfccs_input_non_targets[counter_non_target:counter_non_target +50]])
        print(prediction)

        # Evaluation score with Non-target-scores.
        eval_score = siamese_model.evaluate([test_mfccs[i], mfccs_input_non_targets[counter_non_target:counter_non_target +50]], 
                                            y=[mfccs_input_non_targets[counter_non_target:counter_non_target +50]], verbose=2)
        print(eval_score)

        counter_non_target += 50

# %%
# Test the basic scenario.
test_basic_scenario_siamese(siamese_model_basic, test_set_basic)

# %% [markdown]
# Here is the Test Module for the 3 other scenarios. The DET-curves are not really usable for the 3 scenarios without modifying the test-scenario fist, as the randomly testing yields almost always only same outcome result (not same speaker) which causes the DET-curves to be always blank as the prediction becomes too easy and there are no false negatives or false positives. Use sampling and verbose to modify sampling and DET-curve creation to better visualize the amount of false-negatives and false positives when the data is not so biased.

# %%
# Test given Siamese Model with given Test Samples.
def test_siamese(siamese_model, test_samples, verbose:bool = False, sampling:bool = False):

    # Define array to take scores and y-scores for DET-curve plotting.
    y_pred_scores = []
    y_true_scores = []

    # Get indices from Test Set.
    indices = np.arange(len(test_samples))
    np.random.shuffle(indices)
    indices_clone = np.copy(indices)
    np.random.shuffle(indices_clone)

    # Generate DataFrame based on indices.
    pairwise_map = pd.DataFrame({"sample1": indices, "sample2": indices_clone})

    # If sampling is false, do random picking.
    if sampling == False:
        # Take speakers from Test Set.
        speaker_sample1 = test_samples["spk"].iloc[pairwise_map["sample1"].values].values
        speaker_sample2 = test_samples["spk"].iloc[pairwise_map["sample2"].values].values

        # Check if same speaker.
        y = np.equal(speaker_sample1, speaker_sample2)
        y_true_scores.append(y)

        # Take MFCCs for Test Set.
        mfccs_1 = test_samples["mfcc"].iloc[speaker_sample1].values
        mfccs_2 = test_samples["mfcc"].iloc[speaker_sample2].values

        # Generate correct input format for NNW.
        mfccs_input_1 = np.zeros((len(test_samples), 60, 13))
        mfccs_input_2 = np.zeros((len(test_samples), 60, 13))
        for i in range(len(test_samples)):
            mfccs_input_1[i, :] = mfccs_1[i]
            mfccs_input_2[i, :] = mfccs_2[i]
    
    # if sampling is True, do more equal sampling for providing DET-curves.
    if sampling == True:

        # Take speakers from Test Set.
        speaker_sample1 = test_samples["spk"].iloc[pairwise_map["sample1"].values].values
        speaker_sample2 = []

        # Take MFCCs for Sample Set.
        mfccs_1 = test_samples["mfcc"].iloc[speaker_sample1].values

        # Generate Target-scores MFCC scores for half of the utterances from same speaker for each speaker in first MFCC set.
        mfccs_2_target = []
        for i in range(len(speaker_sample1)//2):
            speaker = speaker_sample1[i]
            speaker_sample2.append(speaker)
            mfccs_speaker = test_samples.loc[test_samples["spk"] == speaker, "mfcc"]
            mfccs_target = random.sample(list(mfccs_speaker), 1)
            mfccs_2_target.append(mfccs_target)
        
        # Generate Non-target scores for the other half.
        mfccs_2_non_target = []
        for i in range(len(speaker_sample1)//2):
            speaker = speaker_sample1[i]
            not_speaker = test_samples.loc[test_samples["spk"] != speaker, "spk"].iloc[0]
            speaker_sample2.append(not_speaker)
            mfccs_not_speaker = test_samples.loc[test_samples["spk"] == not_speaker, "mfcc"]
            mfccs_non_target = random.sample(list(mfccs_not_speaker), 1)
            mfccs_2_non_target.append(mfccs_non_target)

        # Convert to numpy.
        speaker_sample2 = np.array(speaker_sample2)

        # Check if same speaker.
        y = np.equal(speaker_sample1, speaker_sample2)
        y_true_scores.append(y)

        # Combine lists.
        mfccs_2 = mfccs_2_target + mfccs_2_non_target
        mfccs_2 = np.array(mfccs_2)
        
        # Generate correct input format for NNW.
        mfccs_input_1 = np.zeros((len(test_samples), 60, 13))
        mfccs_input_2 = np.zeros((len(test_samples), 60, 13))
        for i in range(len(test_samples)):
            mfccs_input_1[i,:] = mfccs_1[i]
            mfccs_input_2[i,:] = mfccs_2[i]

        
    # Sanity checks.
    print(mfccs_input_1.shape)
    print(mfccs_input_2.shape)

    # Reshape.
    mfccs_input_1 = mfccs_input_1.reshape((-1, 60, 13, 1))
    mfccs_input_2 = mfccs_input_2.reshape((-1, 60, 13, 1))

    # Predict with model.
    print("Predicting with model on Test Set:")
    prediction = siamese_model.predict([mfccs_input_1, mfccs_input_2])
    print(prediction)
    y_pred_scores.append(prediction)

    # Evaluate model with Test Set.
    print("Evaluating the neural network on Test Set:")
    score = siamese_model.evaluate([mfccs_input_1, mfccs_input_2], y=y, verbose=2)
    print(score)

    # Get and plot DET-curves.
    if verbose == True:

      # Convert to NumPy and transpose to use with DET-curve.
      y_pred_scores = np.array(y_pred_scores)
      y_pred_scores = y_pred_scores.reshape((y_pred_scores.shape[0], y_pred_scores.shape[1]))
      y_true_scores = np.array(y_true_scores)

      y_pred_scores = y_pred_scores.T
      y_true_scores = y_true_scores.T

      # Predicted.
      fprate_pred, fnrate_pred, thresholds_pred = det_curve(y_true=y_true_scores, y_score=y_pred_scores, pos_label=None)
      plt.figure()
      display = DetCurveDisplay(
        fpr=fprate_pred, fnr=fnrate_pred, estimator_name='Prediction estimator')
      display.plot()
      plt.show()

# %% [markdown]
# Test the 3 specific different Models. Set verbose = True, to get DET-curves if any plot-able data is provided (not in most cases) and sampling = True to use sampling, to provide more evenly spread labels:

# %%
test_siamese(siamese_model_dependent, test_set_dependent, verbose=False, sampling=False)
# Out:
# (1500, 60, 13)
# (1500, 60, 13)
# Predicting with model on Test Set:
# [[1.3554499e-03]
#  [7.4723430e-02]
#  [7.2426850e-04]
#  ...
#  [2.0185192e-04]
#  [1.3378229e-05]
#  [4.1524320e-08]]
# Evaluating the neural network on Test Set:
# 47/47 - 0s - loss: 0.0258 - accuracy: 0.9907
# [0.025833679363131523, 0.9906666874885559]

# %%
test_siamese(siamese_model_limited, test_set_limited, verbose=False, sampling=False)
# Out:
# (15000, 60, 13)
# (15000, 60, 13)
# Predicting with model on Test Set:
# [[2.2378204e-06]
#  [1.1176424e-07]
#  [6.3211000e-06]
#  ...
#  [2.2873991e-07]
#  [2.4468823e-09]
#  [1.1575268e-06]]
# Evaluating the neural network on Test Set:
# 469/469 - 2s - loss: 0.0050 - accuracy: 0.9993
# [0.004982215818017721, 0.9992666840553284]

# %%
test_siamese(siamese_model_independent, test_set_independent, verbose=False, sampling=False)
# Out:
# (15000, 60, 13)
# (15000, 60, 13)
# Predicting with model on Test Set:
# [[6.1543041e-08]
#  [5.1068071e-02]
#  [2.4015696e-03]
#  ...
#  [9.1181893e-04]
#  [7.1301730e-03]
#  [1.3008282e-05]]
# Evaluating the neural network on Test Set:
# 469/469 - 2s - loss: 0.0079 - accuracy: 0.9994
# [0.007936638779938221, 0.9994000196456909]

# %%
test_siamese(siamese_model_dependent_equal, test_set_dependent, verbose=True, sampling=True)
# Out:
# (1500, 60, 13)
# (1500, 60, 13)
# Predicting with model on Test Set:
# [[0.7857071 ]
#  [0.79213834]
#  [0.79213834]
#  ...
#  [0.79213834]
#  [0.79213834]
#  [0.79213834]]
# Evaluating the neural network on Test Set:
# 47/47 - 0s - loss: 0.9631 - accuracy: 0.5020
# [0.963061511516571, 0.5019999742507935]

# %%
test_siamese(siamese_model_limited_equal, test_set_limited, verbose=True, sampling=True)
# Out:
# (15000, 60, 13)
# (15000, 60, 13)
# Predicting with model on Test Set:
# [[0.7938902]
#  [0.7938902]
#  [0.7938902]
#  ...
#  [0.7938902]
#  [0.7938902]
#  [0.774154 ]]
# Evaluating the neural network on Test Set:
# 469/469 - 2s - loss: 0.6129 - accuracy: 0.8003
# [0.6128866076469421, 0.8003333210945129]

# %%
test_siamese(siamese_model_independent_equal, test_set_independent, verbose=True, sampling=True)
# Out:
# (15000, 60, 13)
# (15000, 60, 13)
# Predicting with model on Test Set:
# [[0.79185367]
#  [0.79185367]
#  [0.79185367]
#  ...
#  [0.79185367]
#  [0.79185367]
#  [0.79185367]]
# Evaluating the neural network on Test Set:
# 469/469 - 2s - loss: 0.9039 - accuracy: 0.5045
# [0.9039191007614136, 0.5045333504676819]

# %% [markdown]
# Test Models with data from other Test Sets.

# %%
# Context dependent with others.
test_siamese(siamese_model_dependent, test_set_basic, verbose=False, sampling=False)
test_siamese(siamese_model_dependent, test_set_limited,verbose=False, sampling=False)
test_siamese(siamese_model_dependent, test_set_independent, verbose=False, sampling=False)

test_siamese(siamese_model_dependent, test_set_basic, verbose=False, sampling=True)
test_siamese(siamese_model_dependent, test_set_limited,verbose=False, sampling=True)
test_siamese(siamese_model_dependent, test_set_independent, verbose=False, sampling=True)
# Out:
# (10000, 60, 13)
# (10000, 60, 13)
# Predicting with model on Test Set:
# [[1.2191788e-03]
#  [1.3101818e-06]
#  [3.2012395e-04]
#  ...
#  [9.6561715e-05]
#  [7.0872419e-03]
#  [1.9788041e-04]]
# Evaluating the neural network on Test Set:
# 313/313 - 1s - loss: 0.0219 - accuracy: 0.9953
# [0.02189450152218342, 0.9952999949455261]
# (15000, 60, 13)
# (15000, 60, 13)
# Predicting with model on Test Set:
# [[3.6653909e-01]
#  [6.1067881e-04]
#  [7.0441509e-08]
#  ...
#  [3.3060529e-03]
#  [8.5194837e-03]
#  [1.4403614e-07]]
# Evaluating the neural network on Test Set:
# 469/469 - 2s - loss: 0.0381 - accuracy: 0.9880
# [0.03805765509605408, 0.9879999756813049]
# (15000, 60, 13)
# (15000, 60, 13)
# Predicting with model on Test Set:
# [[1.5742412e-04]
#  [1.2651686e-01]
#  [3.2932624e-02]
#  ...
#  [6.0002370e-05]
#  [2.5626449e-03]
#  [7.8820630e-09]]
# Evaluating the neural network on Test Set:
# 469/469 - 2s - loss: 0.0456 - accuracy: 0.9949
# [0.045636363327503204, 0.9949333071708679]
# (10000, 60, 13)
# (10000, 60, 13)
# Predicting with model on Test Set:
# [[1.8822575e-03]
#  [2.1308316e-03]
#  [1.1303794e-05]
#  ...
#  [4.9358276e-03]
#  [2.0386396e-06]
#  [5.9484124e-02]]
# Evaluating the neural network on Test Set:
# 313/313 - 2s - loss: 4.9429 - accuracy: 0.4740
# [4.9429450035095215, 0.4740000069141388]
# (15000, 60, 13)
# (15000, 60, 13)
# Predicting with model on Test Set:
# [[1.7032437e-03]
#  [2.0160052e-04]
#  [2.2253573e-03]
#  ...
#  [9.3660647e-06]
#  [9.6876305e-03]
#  [2.2158404e-03]]
# Evaluating the neural network on Test Set:
# 469/469 - 2s - loss: 4.1454 - accuracy: 0.4909
# [4.145384788513184, 0.49086666107177734]
# (15000, 60, 13)
# (15000, 60, 13)
# Predicting with model on Test Set:
# [[5.0866252e-05]
#  [9.6395008e-02]
#  [7.1160107e-06]
#  ...
#  [2.4531102e-02]
#  [1.8284692e-01]
#  [7.6499522e-02]]
# Evaluating the neural network on Test Set:
# 469/469 - 2s - loss: 3.4295 - accuracy: 0.4925
# [3.429452657699585, 0.49246665835380554]

# %%
# Context limited with others.
test_siamese(siamese_model_limited, test_set_basic, verbose=False, sampling=False)
test_siamese(siamese_model_limited, test_set_dependent, verbose=False, sampling=False)
test_siamese(siamese_model_limited, test_set_independent, verbose=False, sampling=False)

test_siamese(siamese_model_limited, test_set_basic, verbose=False, sampling=True)
test_siamese(siamese_model_limited, test_set_dependent, verbose=False, sampling=True)
test_siamese(siamese_model_limited, test_set_independent, verbose=False, sampling=True)
# Out:
# (10000, 60, 13)
# (10000, 60, 13)
# Predicting with model on Test Set:
# [[1.5969299e-05]
#  [2.2270773e-04]
#  [8.8767149e-03]
#  ...
#  [1.6815052e-08]
#  [8.9854425e-01]
#  [6.0259454e-06]]
# Evaluating the neural network on Test Set:
# 313/313 - 1s - loss: 0.0116 - accuracy: 1.0000
# [0.011555643752217293, 1.0]
# (1500, 60, 13)
# (1500, 60, 13)
# Predicting with model on Test Set:
# [[1.4715162e-05]
#  [1.2285209e-05]
#  [1.5232228e-03]
#  ...
#  [4.3067776e-05]
#  [5.5658906e-03]
#  [6.5598493e-07]]
# Evaluating the neural network on Test Set:
# 47/47 - 0s - loss: 0.0126 - accuracy: 0.9993
# [0.01256345584988594, 0.9993333220481873]
# (15000, 60, 13)
# (15000, 60, 13)
# Predicting with model on Test Set:
# [[3.6762797e-03]
#  [6.4135767e-03]
#  [8.0769746e-07]
#  ...
#  [3.8124761e-03]
#  [2.0743173e-06]
#  [1.3047000e-04]]
# Evaluating the neural network on Test Set:
# 469/469 - 2s - loss: 0.0076 - accuracy: 0.9998
# [0.007583635859191418, 0.9998000264167786]
# (10000, 60, 13)
# (10000, 60, 13)
# Predicting with model on Test Set:
# [[2.01008697e-06]
#  [2.00019174e-04]
#  [5.19699825e-04]
#  ...
#  [4.19195858e-04]
#  [3.86933465e-07]
#  [1.13382615e-04]]
# Evaluating the neural network on Test Set:
# 313/313 - 1s - loss: 5.5247 - accuracy: 0.4727
# [5.524710178375244, 0.47269999980926514]
# (1500, 60, 13)
# (1500, 60, 13)
# Predicting with model on Test Set:
# [[2.8941011e-05]
#  [9.5860224e-04]
#  [1.9937902e-04]
#  ...
#  [2.2995108e-01]
#  [2.2114299e-02]
#  [9.1770332e-04]]
# Evaluating the neural network on Test Set:
# 47/47 - 0s - loss: 4.2319 - accuracy: 0.4887
# [4.2319111824035645, 0.4886666536331177]
# (15000, 60, 13)
# (15000, 60, 13)
# Predicting with model on Test Set:
# [[3.29200947e-03]
#  [5.80920459e-05]
#  [3.75697095e-06]
#  ...
#  [9.47964693e-08]
#  [1.12531427e-03]
#  [1.19691904e-04]]
# Evaluating the neural network on Test Set:
# 469/469 - 2s - loss: 4.7464 - accuracy: 0.4918
# [4.7463531494140625, 0.4918000102043152]

# %%
# Context independent with others.
test_siamese(siamese_model_independent, test_set_basic, verbose=False, sampling=False)
test_siamese(siamese_model_independent, test_set_dependent, verbose=False, sampling=False)
test_siamese(siamese_model_independent, test_set_limited, verbose=False, sampling=False)

test_siamese(siamese_model_independent, test_set_basic, verbose=False, sampling=True)
test_siamese(siamese_model_independent, test_set_dependent, verbose=False, sampling=True)
test_siamese(siamese_model_independent, test_set_limited, verbose=False, sampling=True)
# Out:
# (10000, 60, 13)
# (10000, 60, 13)
# Predicting with model on Test Set:
# [[2.7797082e-01]
#  [6.0913574e-02]
#  [2.4866147e-04]
#  ...
#  [6.0913600e-02]
#  [1.1386162e-04]
#  [1.8644199e-04]]
# Evaluating the neural network on Test Set:
# 313/313 - 1s - loss: 0.0449 - accuracy: 0.9839
# [0.04492240771651268, 0.9839000105857849]
# (1500, 60, 13)
# (1500, 60, 13)
# Predicting with model on Test Set:
# [[1.4800455e-06]
#  [3.9554070e-08]
#  [6.5971071e-05]
#  ...
#  [7.0087852e-05]
#  [2.0015305e-03]
#  [3.5957865e-02]]
# Evaluating the neural network on Test Set:
# 47/47 - 0s - loss: 0.0187 - accuracy: 0.9953
# [0.018655288964509964, 0.9953333139419556]
# (15000, 60, 13)
# (15000, 60, 13)
# Predicting with model on Test Set:
# [[2.2738872e-05]
#  [1.6791676e-06]
#  [1.4018206e-03]
#  ...
#  [1.7445784e-07]
#  [1.2169453e-05]
#  [4.3296284e-05]]
# Evaluating the neural network on Test Set:
# 469/469 - 2s - loss: 0.0196 - accuracy: 0.9958
# [0.019570965319871902, 0.9958000183105469]
# (10000, 60, 13)
# (10000, 60, 13)
# Predicting with model on Test Set:
# [[5.7545680e-07]
#  [8.2782326e-06]
#  [1.5230904e-05]
#  ...
#  [8.4171690e-02]
#  [7.5366336e-04]
#  [2.5163406e-01]]
# Evaluating the neural network on Test Set:
# 313/313 - 1s - loss: 4.9835 - accuracy: 0.4672
# [4.983499050140381, 0.46720001101493835]
# (1500, 60, 13)
# (1500, 60, 13)
# Predicting with model on Test Set:
# [[1.5034239e-02]
#  [5.5002311e-04]
#  [7.5689480e-03]
#  ...
#  [1.9903777e-05]
#  [1.7978374e-03]
#  [5.6401908e-04]]
# Evaluating the neural network on Test Set:
# 47/47 - 0s - loss: 4.3002 - accuracy: 0.4933
# [4.3002142906188965, 0.4933333396911621]
# (15000, 60, 13)
# (15000, 60, 13)
# Predicting with model on Test Set:
# [[1.1142784e-03]
#  [9.1612677e-08]
#  [6.9998589e-07]
#  ...
#  [5.8015019e-09]
#  [6.2127533e-06]
#  [2.7767190e-05]]
# Evaluating the neural network on Test Set:
# 469/469 - 2s - loss: 5.1573 - accuracy: 0.4906
# [5.157261848449707, 0.49059998989105225]

# %% [markdown]
# Test Models with Models trained with more equally distributed data.

# %%
# Context dependent with others.
test_siamese(siamese_model_dependent_equal, test_set_basic, verbose=False, sampling=False)
test_siamese(siamese_model_dependent_equal, test_set_limited,verbose=False, sampling=False)
test_siamese(siamese_model_dependent_equal, test_set_independent, verbose=False, sampling=False)

test_siamese(siamese_model_dependent_equal, test_set_basic, verbose=False, sampling=True)
test_siamese(siamese_model_dependent_equal, test_set_limited,verbose=False, sampling=True)
test_siamese(siamese_model_dependent_equal, test_set_independent, verbose=False, sampling=True)
# Out:
# (10000, 60, 13)
# (10000, 60, 13)
# Predicting with model on Test Set:
# [[0.79213834]
#  [0.79213834]
#  [0.79213834]
#  ...
#  [0.79213834]
#  [0.79213834]
#  [0.79213834]]
# Evaluating the neural network on Test Set:
# 313/313 - 1s - loss: 1.5060 - accuracy: 0.0485
# [1.5059990882873535, 0.048500001430511475]
# (15000, 60, 13)
# (15000, 60, 13)
# Predicting with model on Test Set:
# [[0.79213834]
#  [0.79213834]
#  [0.79213834]
#  ...
#  [0.79213834]
#  [0.79213834]
#  [0.79213834]]
# Evaluating the neural network on Test Set:
# 469/469 - 2s - loss: 1.5482 - accuracy: 0.0169
# [1.5482242107391357, 0.01693333312869072]
# (15000, 60, 13)
# (15000, 60, 13)
# Predicting with model on Test Set:
# [[0.79213834]
#  [0.79213834]
#  [0.79213834]
#  ...
#  [0.79213834]
#  [0.79213834]
#  [0.79213834]]
# Evaluating the neural network on Test Set:
# 469/469 - 2s - loss: 1.5488 - accuracy: 0.0165
# [1.5488485097885132, 0.016466666013002396]
# (10000, 60, 13)
# (10000, 60, 13)
# Predicting with model on Test Set:
# [[0.79213834]
#  [0.79213834]
#  [0.79213834]
#  ...
#  [0.79213834]
#  [0.79213834]
#  [0.79213834]]
# Evaluating the neural network on Test Set:
# 313/313 - 1s - loss: 0.8672 - accuracy: 0.5245
# [0.8671520352363586, 0.5245000123977661]
# (15000, 60, 13)
# (15000, 60, 13)
# Predicting with model on Test Set:
# [[0.79213834]
#  [0.79213834]
#  [0.79213834]
#  ...
#  [0.79213834]
#  [0.79213834]
#  [0.79213834]]
# Evaluating the neural network on Test Set:
# 469/469 - 2s - loss: 0.8228 - accuracy: 0.5568
# [0.8227808475494385, 0.5568000078201294]
# (15000, 60, 13)
# (15000, 60, 13)
# Predicting with model on Test Set:
# [[0.79213834]
#  [0.79213834]
#  [0.79213834]
#  ...
#  [0.79213834]
#  [0.79213834]
#  [0.79213834]]
# Evaluating the neural network on Test Set:
# 469/469 - 2s - loss: 0.9051 - accuracy: 0.5045
# [0.9050747156143188, 0.5044666528701782]

# %%
# Context limited with others.
test_siamese(siamese_model_limited_equal, test_set_basic, verbose=False, sampling=False)
test_siamese(siamese_model_limited_equal, test_set_dependent, verbose=False, sampling=False)
test_siamese(siamese_model_limited_equal, test_set_independent, verbose=False, sampling=False)

test_siamese(siamese_model_limited_equal, test_set_basic, verbose=False, sampling=True)
test_siamese(siamese_model_limited_equal, test_set_dependent, verbose=False, sampling=True)
test_siamese(siamese_model_limited_equal, test_set_independent, verbose=False, sampling=True)
# Out:
# (10000, 60, 13)
# (10000, 60, 13)
# Predicting with model on Test Set:
# [[0.7938902]
#  [0.7938902]
#  [0.7938902]
#  ...
#  [0.7938902]
#  [0.7938902]
#  [0.7938902]]
# Evaluating the neural network on Test Set:
# 313/313 - 1s - loss: 1.5168 - accuracy: 0.0464
# [1.5167713165283203, 0.04639999940991402]
# (1500, 60, 13)
# (1500, 60, 13)
# Predicting with model on Test Set:
# [[0.7938902]
#  [0.7938902]
#  [0.7938902]
#  ...
#  [0.7938902]
#  [0.7938902]
#  [0.6864512]]
# Evaluating the neural network on Test Set:
# 47/47 - 0s - loss: 1.4960 - accuracy: 0.0487
# [1.4960353374481201, 0.04866666719317436]
# (15000, 60, 13)
# (15000, 60, 13)
# Predicting with model on Test Set:
# [[0.7938902]
#  [0.7938902]
#  [0.7938902]
#  ...
#  [0.7938902]
#  [0.7938902]
#  [0.7938902]]
# Evaluating the neural network on Test Set:
# 469/469 - 2s - loss: 1.5080 - accuracy: 0.0484
# [1.5079575777053833, 0.04839999973773956]
# (10000, 60, 13)
# (10000, 60, 13)
# Predicting with model on Test Set:
# [[0.7938902]
#  [0.7938902]
#  [0.7938902]
#  ...
#  [0.7938902]
#  [0.7938902]
#  [0.7938902]]
# Evaluating the neural network on Test Set:
# 313/313 - 1s - loss: 0.8682 - accuracy: 0.5274
# [0.8682374954223633, 0.527400016784668]
# (1500, 60, 13)
# (1500, 60, 13)
# Predicting with model on Test Set:
# [[7.9389018e-01]
#  [7.9389018e-01]
#  [6.2795397e-04]
#  ...
#  [7.9389018e-01]
#  [7.9389018e-01]
#  [7.9389018e-01]]
# Evaluating the neural network on Test Set:
# 47/47 - 0s - loss: 1.0039 - accuracy: 0.4947
# [1.003911018371582, 0.4946666657924652]
# (15000, 60, 13)
# (15000, 60, 13)
# Predicting with model on Test Set:
# [[0.7938902 ]
#  [0.7938902 ]
#  [0.04331413]
#  ...
#  [0.7938902 ]
#  [0.7938902 ]
#  [0.7938902 ]]
# Evaluating the neural network on Test Set:
# 469/469 - 2s - loss: 0.9550 - accuracy: 0.4987
# [0.9549785256385803, 0.4986666738986969]

# %%
# Context independent with others.
test_siamese(siamese_model_independent_equal, test_set_basic, verbose=False, sampling=False)
test_siamese(siamese_model_independent_equal, test_set_dependent, verbose=False, sampling=False)
test_siamese(siamese_model_independent_equal, test_set_limited, verbose=False, sampling=False)

test_siamese(siamese_model_independent_equal, test_set_basic, verbose=False, sampling=True)
test_siamese(siamese_model_independent_equal, test_set_dependent, verbose=False, sampling=True)
test_siamese(siamese_model_independent_equal, test_set_limited, verbose=False, sampling=True)
# Out:
# (10000, 60, 13)
# (10000, 60, 13)
# Predicting with model on Test Set:
# [[0.79185367]
#  [0.79185367]
#  [0.79185367]
#  ...
#  [0.79185367]
#  [0.79185367]
#  [0.79185367]]
# Evaluating the neural network on Test Set:
# 313/313 - 1s - loss: 1.5035 - accuracy: 0.0494
# [1.5035078525543213, 0.049400001764297485]
# (1500, 60, 13)
# (1500, 60, 13)
# Predicting with model on Test Set:
# [[0.79185367]
#  [0.79185367]
#  [0.79185367]
#  ...
#  [0.79185367]
#  [0.79185367]
#  [0.79185367]]
# Evaluating the neural network on Test Set:
# 47/47 - 0s - loss: 1.5410 - accuracy: 0.0213
# [1.5410099029541016, 0.02133333310484886]
# (15000, 60, 13)
# (15000, 60, 13)
# Predicting with model on Test Set:
# [[0.79185367]
#  [0.79185367]
#  [0.79185367]
#  ...
#  [0.79185367]
#  [0.79185367]
#  [0.79185367]]
# Evaluating the neural network on Test Set:
# 469/469 - 2s - loss: 1.5467 - accuracy: 0.0171
# [1.546715259552002, 0.01706666685640812]
# (10000, 60, 13)
# (10000, 60, 13)
# Predicting with model on Test Set:
# [[0.79185367]
#  [0.79185367]
#  [0.79185367]
#  ...
#  [0.79185367]
#  [0.79185367]
#  [0.79185367]]
# Evaluating the neural network on Test Set:
# 313/313 - 1s - loss: 0.8771 - accuracy: 0.5242
# [0.8771318197250366, 0.5242000222206116]
# (1500, 60, 13)
# (1500, 60, 13)
# Predicting with model on Test Set:
# [[0.79185367]
#  [0.79185367]
#  [0.79185367]
#  ...
#  [0.79185367]
#  [0.79185367]
#  [0.79185367]]
# Evaluating the neural network on Test Set:
# 47/47 - 0s - loss: 0.8917 - accuracy: 0.5073
# [0.8916555047035217, 0.5073333382606506]
# (15000, 60, 13)
# (15000, 60, 13)
# Predicting with model on Test Set:
# [[0.79185367]
#  [0.79185367]
#  [0.79185367]
#  ...
#  [0.79185367]
#  [0.79185367]
#  [0.79185367]]
# Evaluating the neural network on Test Set:
# 469/469 - 2s - loss: 0.9327 - accuracy: 0.5019
# [0.9326928853988647, 0.5019333362579346]

# %% [markdown]
# In conclusion, there is still lot to do and lots of problemns to be solved. The training of Siamese Neural Network for the first time has proven to have many challenges, which can be definitely overcome in future.
#
# The training of the Models and the scenarios for this project were interesting, yet not the most "easy", when thinking about how much there was to be learned in order to understand why the scenarios worked as they did and why I could not expect really good results from the Models learning or prediction wise.
#
# All in all, the project was very good learning experience and it was quite shame some of the ""little things" in data handling and srugling a bit with the shapes of inputs etc. took a lot of time (as I have not been too familiar with the concept before), thus reducing the amount of time spended with the actual NNW part of the work (as it would have been nice to make them actually work better).
#
# This project was quite inspiring (even tho pretty hard), but in order to get more accurate and relatable Models for Automatic Speaker Verification a lot has to be done to improve the setup made in this project so far.
